# %% [markdown]
# This is a demonstration of the use of GFDL generated intake_esm catalogs on the ocean daily field zos.
# Reference: https://github.com/aradhakrishnanGFDL/canopy-cats

# %%
import xarray as xr
import intake,yaml,os
import intake_esm

import warnings
warnings.filterwarnings("ignore")

# %%
print(intake_esm.__version__)
# Out:
# 2023.7.7

# %% [markdown]
# INSERT THE LOCATION OF YOUR DATA CATALOG IN THE CELL BELOW TO EXPLORE SOMETHING ELSE

# %%
#col_url = "/home/c2b/catalog/catalog3.json"
col_url = "/home/a1r/git/canopy-cats/catalogs/gfdl_eg/catalog3.json" #with na for optional column member_id instead of empty

# %%
col = intake.open_esm_datastore(col_url)

# %% [markdown]
# Explore the catalog by viewing the "data frame" (df)

# %%
col.df
# Out:
#      activity_id institution_id source_id          experiment_id frequency  \
# 0            dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 1            dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 2            dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 3            dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 4            dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# ...          ...            ...       ...                    ...       ...
# 1508         dev            NaN       am5              am5f5b8r0        av
# 1509         dev            NaN       am5              am5f5b8r0        av
# 1510         dev            NaN       am5              am5f5b8r0        av
# 1511         dev            NaN       am5              am5f5b8r0        av
# 1512         dev            NaN       am5              am5f5b8r0        av
#
#      modeling_realm table_id member_id grid_label variable_id temporal_subset  \
# 0     atmos_diurnal      NaN        na        NaN         tas   198501-198512
# 1     atmos_diurnal      NaN        na        NaN     evspsbl   197901-197912
# 2     atmos_diurnal      NaN        na        NaN    z_Ri_025   198401-198412
# 3     atmos_diurnal      NaN        na        NaN        hfss   197901-197912
# 4     atmos_diurnal      NaN        na        NaN          pr   198501-198512
# ...             ...      ...       ...        ...         ...             ...
# 1508      pp_canopy      NaN       NaN        NaN          08            2020
# 1509      pp_canopy      NaN       NaN        NaN          09            2020
# 1510      pp_canopy      NaN       NaN        NaN          10            2020
# 1511      pp_canopy      NaN       NaN        NaN          11            2020
# 1512      pp_canopy      NaN       NaN        NaN          12            2020
#
#        chunk_freq grid_label.1                       platform dimensions  \
# 0             P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 1             P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 2             P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 3             P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 4             P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# ...           ...          ...                            ...        ...
# 1508  monthly_1yr          NaN          c96L65_am5f5b8r0_amip        NaN
# 1509  monthly_1yr          NaN          c96L65_am5f5b8r0_amip        NaN
# 1510  monthly_1yr          NaN          c96L65_am5f5b8r0_amip        NaN
# 1511  monthly_1yr          NaN          c96L65_am5f5b8r0_amip        NaN
# 1512  monthly_1yr          NaN          c96L65_am5f5b8r0_amip        NaN
#
#        cell_methods                                               path
# 0                ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 1                ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 2                ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 3                ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 4                ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# ...             ...                                                ...
# 1508  atmos_diurnal  /archive/am5/am5/am5f5b8r0/c96L65_am5f5b8r0_am...
# 1509  atmos_diurnal  /archive/am5/am5/am5f5b8r0/c96L65_am5f5b8r0_am...
# 1510  atmos_diurnal  /archive/am5/am5/am5f5b8r0/c96L65_am5f5b8r0_am...
# 1511  atmos_diurnal  /archive/am5/am5/am5f5b8r0/c96L65_am5f5b8r0_am...
# 1512  atmos_diurnal  /archive/am5/am5/am5f5b8r0/c96L65_am5f5b8r0_am...
#
# [1513 rows x 17 columns]

# %% [markdown]
# #lets search for variables that I may need for my analysis

# %%
#Examples to just seom5_b02_minthick1em3_MLErestartarch for what we want from the catalog
expname_filter = ['c96L65_am5f6b9r0_amip']
modeling_realm = 'atmos_diurnal'
variable_id_filter = "tas"
frequency = "P1M"

# %%
cat = col.search(experiment_id=expname_filter,frequency=frequency,modeling_realm=modeling_realm, variable_id = variable_id_filter)

# %%
cat
# Out:
# <p><strong>esm_catalog_ESM4 catalog with 1 dataset(s) from 42 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>modeling_realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>temporal_subset</th>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>chunk_freq</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_label.1</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>platform</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>dimensions</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>cell_methods</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# If the files are in /archive, use the following dmgetmagic() to bring the files online before proceeding.

# %%
#for simple dmget usage, just use this !dmget {file}
#use following to wrap the dmget call for each path in the catalog
def dmgetmagic(x):
    cmd = 'dmget %s'% str(x) 
    return os.system(cmd)

#OR refer to importing dmget ,  https://github.com/aradhakrishnanGFDL/canopy-cats/tree/main/notebooks/dmget.py

# %%
cat.df["path"]
# Out:
# 0     /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 1     /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 2     /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 3     /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 4     /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 5     /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 6     /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 7     /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 8     /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 9     /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 10    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 11    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 12    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 13    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 14    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 15    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 16    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 17    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 18    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 19    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 20    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 21    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 22    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 23    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 24    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 25    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 26    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 27    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 28    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 29    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 30    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 31    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 32    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 33    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 34    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 35    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 36    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 37    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 38    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 39    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 40    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 41    /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# Name: path, dtype: object

# %%
dmstatus = cat.df["path"].apply(dmgetmagic)

# %%
cat.df
# Out:
#    activity_id institution_id source_id          experiment_id frequency  \
# 0          dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 1          dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 2          dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 3          dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 4          dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 5          dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 6          dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 7          dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 8          dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 9          dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 10         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 11         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 12         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 13         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 14         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 15         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 16         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 17         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 18         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 19         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 20         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 21         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 22         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 23         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 24         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 25         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 26         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 27         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 28         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 29         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 30         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 31         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 32         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 33         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 34         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 35         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 36         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 37         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 38         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 39         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 40         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
# 41         dev            NaN       am5  c96L65_am5f6b9r0_amip       P1M
#
#    modeling_realm table_id member_id grid_label variable_id temporal_subset  \
# 0   atmos_diurnal      NaN        na        NaN         tas   198501-198512
# 1   atmos_diurnal      NaN        na        NaN         tas   197901-197912
# 2   atmos_diurnal      NaN        na        NaN         tas   198601-198612
# 3   atmos_diurnal      NaN        na        NaN         tas   198001-198012
# 4   atmos_diurnal      NaN        na        NaN         tas   198701-198712
# 5   atmos_diurnal      NaN        na        NaN         tas   198101-198112
# 6   atmos_diurnal      NaN        na        NaN         tas   198801-198812
# 7   atmos_diurnal      NaN        na        NaN         tas   198201-198212
# 8   atmos_diurnal      NaN        na        NaN         tas   198901-198912
# 9   atmos_diurnal      NaN        na        NaN         tas   198301-198312
# 10  atmos_diurnal      NaN        na        NaN         tas   199001-199012
# 11  atmos_diurnal      NaN        na        NaN         tas   198401-198412
# 12  atmos_diurnal      NaN        na        NaN         tas   199101-199112
# 13  atmos_diurnal      NaN        na        NaN         tas   199201-199212
# 14  atmos_diurnal      NaN        na        NaN         tas   199301-199312
# 15  atmos_diurnal      NaN        na        NaN         tas   199401-199412
# 16  atmos_diurnal      NaN        na        NaN         tas   199501-199512
# 17  atmos_diurnal      NaN        na        NaN         tas   199701-199712
# 18  atmos_diurnal      NaN        na        NaN         tas   199801-199812
# 19  atmos_diurnal      NaN        na        NaN         tas   199601-199612
# 20  atmos_diurnal      NaN        na        NaN         tas   199901-199912
# 21  atmos_diurnal      NaN        na        NaN         tas   200001-200012
# 22  atmos_diurnal      NaN        na        NaN         tas   200101-200112
# 23  atmos_diurnal      NaN        na        NaN         tas   200201-200212
# 24  atmos_diurnal      NaN        na        NaN         tas   200301-200312
# 25  atmos_diurnal      NaN        na        NaN         tas   200401-200412
# 26  atmos_diurnal      NaN        na        NaN         tas   200501-200512
# 27  atmos_diurnal      NaN        na        NaN         tas   200601-200612
# 28  atmos_diurnal      NaN        na        NaN         tas   200701-200712
# 29  atmos_diurnal      NaN        na        NaN         tas   200801-200812
# 30  atmos_diurnal      NaN        na        NaN         tas   200901-200912
# 31  atmos_diurnal      NaN        na        NaN         tas   201001-201012
# 32  atmos_diurnal      NaN        na        NaN         tas   201101-201112
# 33  atmos_diurnal      NaN        na        NaN         tas   201201-201212
# 34  atmos_diurnal      NaN        na        NaN         tas   201301-201312
# 35  atmos_diurnal      NaN        na        NaN         tas   201401-201412
# 36  atmos_diurnal      NaN        na        NaN         tas   201501-201512
# 37  atmos_diurnal      NaN        na        NaN         tas   201601-201612
# 38  atmos_diurnal      NaN        na        NaN         tas   201701-201712
# 39  atmos_diurnal      NaN        na        NaN         tas   201801-201812
# 40  atmos_diurnal      NaN        na        NaN         tas   201901-201912
# 41  atmos_diurnal      NaN        na        NaN         tas   202001-202012
#
#    chunk_freq grid_label.1                       platform dimensions  \
# 0         P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 1         P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 2         P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 3         P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 4         P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 5         P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 6         P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 7         P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 8         P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 9         P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 10        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 11        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 12        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 13        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 14        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 15        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 16        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 17        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 18        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 19        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 20        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 21        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 22        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 23        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 24        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 25        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 26        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 27        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 28        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 29        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 30        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 31        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 32        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 33        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 34        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 35        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 36        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 37        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 38        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 39        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 40        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
# 41        P1Y          NaN  gfdl.ncrc5-deploy-prod-openmp        NaN
#
#    cell_methods                                               path
# 0            ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 1            ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 2            ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 3            ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 4            ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 5            ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 6            ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 7            ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 8            ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 9            ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 10           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 11           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 12           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 13           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 14           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 15           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 16           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 17           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 18           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 19           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 20           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 21           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 22           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 23           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 24           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 25           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 26           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 27           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 28           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 29           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 30           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 31           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 32           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 33           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 34           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 35           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 36           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 37           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 38           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 39           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 40           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...
# 41           ts  /archive/am5/am5/am5f6b9r0/c96L65_am5f6b9r0_am...

# %% [raw]
# Now, we are getting ready for analysis.
# Organizing as dictionary:
#     experiment.frequency.realm.variable as the KEY
#     The value of the dictionary maps to an xarray dataset object.
#     Each xarray dataset object has dimensions, coordinates, etc. In particular,
#     they have the variables listed in the dataset accessible as xarray data arrays.

# %%
dset_dict = cat.to_dataset_dict(cdf_kwargs={'chunks': {'time':5}, 'decode_times': False})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'source_id.experiment_id.frequency.modeling_realm.variable_id.chunk_freq'
#  |████████████████████████████████████████| 100.00% [1/1 00:13<00:00]

# %%
for k in dset_dict.keys(): 
    print(k)
# Out:
# am5.c96L65_am5f6b9r0_amip.P1M.atmos_diurnal.tas.P1Y

# %%
ds = dset_dict["am5.c96L65_am5f6b9r0_amip.P1M.atmos_diurnal.tas.P1Y"]

# %%
ds #the xarray dataset object
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:         (time: 504, bnds: 2, lon: 288, lat: 180, time_of_day_24: 24)
# Coordinates:
#   * time            (time) float64 4kB 15.5 45.0 74.5 ... 1.53e+04 1.533e+04
#     time_bnds       (time, bnds) float64 8kB dask.array<chunksize=(5, 2), meta=np.ndarray>
#   * lon             (lon) float64 2kB 0.625 1.875 3.125 ... 356.9 358.1 359.4
#     lon_bnds        (lon, bnds) float64 5kB dask.array<chunksize=(288, 2), meta=np.ndarray>
#   * lat             (lat) float64 1kB -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#     lat_bnds        (lat, bnds) float64 3kB dask.array<chunksize=(180, 2), meta=np.ndarray>
#   * time_of_day_24  (time_of_day_24) float64 192B 0.5 1.5 2.5 ... 21.5 22.5 23.5
# Dimensions without coordinates: bnds
# Data variables:
#     tas             (time, time_of_day_24, lat, lon) float32 3GB dask.array<chunksize=(5, 24, 180, 288), meta=np.ndarray>
# Attributes: (12/20)
#     CDI:                              Climate Data Interface version 2.1.1 (h...
#     Conventions:                      CF-1.6
#     title:                            c96L65_am5f6b9r0_amip
#     grid_type:                        regular
#     grid_tile:                        N/A
#     code_release_version:             2023.01.02
#     ...                               ...
#     intake_esm_attrs:variable_id:     tas
#     intake_esm_attrs:chunk_freq:      P1Y
#     intake_esm_attrs:platform:        gfdl.ncrc5-deploy-prod-openmp
#     intake_esm_attrs:cell_methods:    ts
#     intake_esm_attrs:_data_format_:   netcdf
#     intake_esm_dataset_key:           am5.c96L65_am5f6b9r0_amip.P1M.atmos_diu...

# %%
len(ds.time)
# Out:
# 504

# %%
ds.tas #data array
# Out:
# <xarray.DataArray 'tas' (time: 504, time_of_day_24: 24, lat: 180, lon: 288)> Size: 3GB
# dask.array<concatenate, shape=(504, 24, 180, 288), dtype=float32, chunksize=(5, 24, 180, 288), chunktype=numpy.ndarray>
# Coordinates:
#   * time            (time) float64 4kB 15.5 45.0 74.5 ... 1.53e+04 1.533e+04
#   * lon             (lon) float64 2kB 0.625 1.875 3.125 ... 356.9 358.1 359.4
#   * lat             (lat) float64 1kB -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * time_of_day_24  (time_of_day_24) float64 192B 0.5 1.5 2.5 ... 21.5 22.5 23.5
# Attributes:
#     standard_name:  air_temperature
#     long_name:      Near-Surface Air Temperature
#     units:          K
#     cell_methods:   time: mean
#     cell_measures:  area: area
#     time_avg_info:  average_T1,average_T2,average_DT
#     interp_method:  conserve_order2

# %% [markdown]
# test2: add ensemble member

# %%
col_url2 = "/home/a1r/git/canopy-cats/catalogs/gfdl_eg/catalog4.json"
col2 = intake.open_esm_datastore(col_url2)

# %%
col2
# Out:
# <p><strong>esm_catalog_ESM4 catalog with 37 dataset(s) from 1513 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>modeling_realm</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>temporal_subset</th>
#       <td>85</td>
#     </tr>
#     <tr>
#       <th>chunk_freq</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>grid_label.1</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>platform</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>dimensions</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>cell_methods</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>1513</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>
