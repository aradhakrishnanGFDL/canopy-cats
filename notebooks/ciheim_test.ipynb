# %%
#import matplotlib
#from matplotlib import pyplot as plt
import xarray as xr
import intake,yaml
import intake_esm

# %%
print(intake_esm.__version__)
# Out:
# 2023.7.7

# %%
#%pip install matplotlib

# %%
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
col_url = "/home/Ciheim.Brown/CatalogBuilder/gfdl_test1.json"

# %%
col = intake.open_esm_datastore(col_url)
# Out:
# /nbhome/a1r/miniconda3/envs/intake/lib/python3.9/site-packages/intake_esm/cat.py:269: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   self._df.sample(20, replace=True)

# %%
col.df
# Out:
#      activity_id  institution_id  source_id                 experiment_id  \
# 0            dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 1            dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 2            dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 3            dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 4            dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# ...          ...             ...        ...                           ...
# 6405         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 6406         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 6407         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 6408         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 6409         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
#
#      frequency modeling_realm  table_id  member_id  grid_label  \
# 0          3hr     atmos_cmip       NaN        NaN         NaN
# 1          3hr     atmos_cmip       NaN        NaN         NaN
# 2          3hr     atmos_cmip       NaN        NaN         NaN
# 3          3hr     atmos_cmip       NaN        NaN         NaN
# 4          3hr     atmos_cmip       NaN        NaN         NaN
# ...        ...            ...       ...        ...         ...
# 6405   monthly      land_cmip       NaN        NaN         NaN
# 6406   monthly      land_cmip       NaN        NaN         NaN
# 6407   monthly      land_cmip       NaN        NaN         NaN
# 6408   monthly      land_cmip       NaN        NaN         NaN
# 6409   monthly      land_cmip       NaN        NaN         NaN
#
#          variable_id  temporal_subset  chunk_freq  grid_label.1  platform  \
# 0                 pr              NaN         NaN           NaN       NaN
# 1               rlut              NaN         NaN           NaN       NaN
# 2                 pr              NaN         NaN           NaN       NaN
# 3               rlut              NaN         NaN           NaN       NaN
# 4                 pr              NaN         NaN           NaN       NaN
# ...              ...              ...         ...           ...       ...
# 6405  treeFracNdlDcd              NaN         NaN           NaN       NaN
# 6406  treeFracNdlEvg              NaN         NaN           NaN       NaN
# 6407             tsl              NaN         NaN           NaN       NaN
# 6408         vegFrac              NaN         NaN           NaN       NaN
# 6409       vegHeight              NaN         NaN           NaN       NaN
#
#       dimensions  cell_methods  \
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# ...          ...           ...
# 6405         NaN           NaN
# 6406         NaN           NaN
# 6407         NaN           NaN
# 6408         NaN           NaN
# 6409         NaN           NaN
#
#                                                    path
# 0     /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 1     /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 2     /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 3     /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 4     /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# ...                                                 ...
# 6405  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 6406  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 6407  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 6408  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 6409  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
#
# [6410 rows x 17 columns]

# %%
#lets search for variables that I may need for my analysis

# %%
#Examples to just search for what we want from the catalog
expname_filter = ['c96L65_am5f3b1r0_pdclim1850F']
modeling_realm = 'atmos_cmip'
variable_id_filter = "tas"
frequency = "monthly"

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
cat = col.search(experiment_id=expname_filter,frequency=frequency,modeling_realm=modeling_realm, variable_id = variable_id_filter)

# %%
cat
# Out:
# <p><strong>esm_catalog_ESM4 catalog with 1 dataset(s) from 10 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>modeling_realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>temporal_subset</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>chunk_freq</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>grid_label.1</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>platform</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>dimensions</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>cell_methods</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cat.df
# Out:
#   activity_id  institution_id  source_id                 experiment_id  \
# 0         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 1         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 2         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 3         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 4         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 5         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 6         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 7         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 8         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
# 9         dev             NaN        NaN  c96L65_am5f3b1r0_pdclim1850F
#
#   frequency modeling_realm  table_id  member_id  grid_label variable_id  \
# 0   monthly     atmos_cmip       NaN        NaN         NaN         tas
# 1   monthly     atmos_cmip       NaN        NaN         NaN         tas
# 2   monthly     atmos_cmip       NaN        NaN         NaN         tas
# 3   monthly     atmos_cmip       NaN        NaN         NaN         tas
# 4   monthly     atmos_cmip       NaN        NaN         NaN         tas
# 5   monthly     atmos_cmip       NaN        NaN         NaN         tas
# 6   monthly     atmos_cmip       NaN        NaN         NaN         tas
# 7   monthly     atmos_cmip       NaN        NaN         NaN         tas
# 8   monthly     atmos_cmip       NaN        NaN         NaN         tas
# 9   monthly     atmos_cmip       NaN        NaN         NaN         tas
#
#    temporal_subset  chunk_freq  grid_label.1  platform  dimensions  \
# 0              NaN         NaN           NaN       NaN         NaN
# 1              NaN         NaN           NaN       NaN         NaN
# 2              NaN         NaN           NaN       NaN         NaN
# 3              NaN         NaN           NaN       NaN         NaN
# 4              NaN         NaN           NaN       NaN         NaN
# 5              NaN         NaN           NaN       NaN         NaN
# 6              NaN         NaN           NaN       NaN         NaN
# 7              NaN         NaN           NaN       NaN         NaN
# 8              NaN         NaN           NaN       NaN         NaN
# 9              NaN         NaN           NaN       NaN         NaN
#
#    cell_methods                                               path
# 0           NaN  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 1           NaN  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 2           NaN  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 3           NaN  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 4           NaN  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 5           NaN  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 6           NaN  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 7           NaN  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 8           NaN  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...
# 9           NaN  /archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pd...

# %%
dset_dict = cat.to_dataset_dict(cdf_kwargs={'chunks': {'time':5}, 'decode_times': False})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'experiment_id.frequency.modeling_realm.variable_id'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:02<00:00]
#     </div>

# %%
for k in dset_dict.keys(): 
    print(k)
# Out:
# c96L65_am5f3b1r0_pdclim1850F.monthly.atmos_cmip.tas

# %%
ds = dset_dict["c96L65_am5f3b1r0_pdclim1850F.monthly.atmos_cmip.tas"]

# %%
len(ds.time)
# Out:
# 120

# %%
ds.tas
# Out:
# <xarray.DataArray 'tas' (time: 120, lat: 180, lon: 288)>
# dask.array<concatenate, shape=(120, 180, 288), dtype=float32, chunksize=(5, 180, 288), chunktype=numpy.ndarray>
# Coordinates:
#     average_DT  (time) float64 dask.array<chunksize=(5,), meta=np.ndarray>
#     average_T1  (time) float64 dask.array<chunksize=(5,), meta=np.ndarray>
#     average_T2  (time) float64 dask.array<chunksize=(5,), meta=np.ndarray>
#     height      float64 2.0
#   * lat         (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#   * lon         (lon) float64 0.625 1.875 3.125 4.375 ... 356.9 358.1 359.4
#   * time        (time) float64 380.5 410.0 439.5 ... 3.938e+03 3.969e+03 4e+03
# Attributes:
#     units:          K
#     long_name:      Near-Surface Air Temperature
#     cell_methods:   time: mean
#     cell_measures:  area: area
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  air_temperature
#     interp_method:  conserve_order2

# %%
tas2d = ds.tas.isel(time=1).plot()
