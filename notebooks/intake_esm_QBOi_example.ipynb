# %% [markdown]
# Authors: A.Radhakrishnan, GFDL
# Ack: Anderson Banihirwe for intake-esm updates, GFDL colleagues for data

# %%
from netCDF4 import Dataset
import numpy as np
#import matplotlib
#from matplotlib import pyplot as plt
import xarray as xr
import intake,yaml
import intake_esm
import numpy as np
#%matplotlib inline

# %% [markdown]
# More cloud-based intake-esm catalog references
#
# esgf-world.json is the ESM collections spec file for the netCDF data in the S3 bucket esgf-world.
# The catalog is updated on an on-demand basis for now.
# You can refer to https://github.com/aradhakrishnanGFDL/gfdl-aws-analysis/tree/community/esm-collection-spec-examples for the most recent catalogs
# More examples can be found in https://github.com/aradhakrishnanGFDL/gfdl-aws-analysis/tree/community/examples

# %% [markdown]
# Use intake-esm catalog put together for QBOiExp1 example with 2 variables only

# %%
col_url = "/home/a1r/cat/canopy/intake_QBOiExp1.json"

# %%
col = intake.open_esm_datastore(col_url)

# %%
col.df
# Out:
#    project  institute      model experiment_id frequency modeling_realm  \
# 0     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 1     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 2     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 3     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 4     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 5     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 6     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 7     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 8     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 9     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 10    QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 11    QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 12    QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 13    QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 14    QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 15    QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
#
#    mip_table ensemble_member grid_label variable temporal subset version  \
# 0         na        r1i1p1f1         gn       ta   198001-198412      na
# 1         na        r1i1p1f1         gn       ta   198501-198912      na
# 2         na        r1i1p1f1         gn       ta   199001-199412      na
# 3         na        r1i1p1f1         gn       ta   199501-199912      na
# 4         na        r1i1p1f1         gn       ta   200001-200412      na
# 5         na        r1i1p1f1         gn       ta   200501-200912      na
# 6         na        r1i1p1f1         gn       ta   201001-201412      na
# 7         na        r1i1p1f1         gn       ta   201501-201912      na
# 8         na        r1i1p1f1         gn      hus   198001-198412      na
# 9         na        r1i1p1f1         gn      hus   198501-198912      na
# 10        na        r1i1p1f1         gn      hus   199001-199412      na
# 11        na        r1i1p1f1         gn      hus   199501-199912      na
# 12        na        r1i1p1f1         gn      hus   200001-200412      na
# 13        na        r1i1p1f1         gn      hus   200501-200912      na
# 14        na        r1i1p1f1         gn      hus   201001-201412      na
# 15        na        r1i1p1f1         gn      hus   201501-201912      na
#
#                                                  path
# 0   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 1   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 2   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 3   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 4   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 5   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 6   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 7   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 8   /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 9   /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 10  /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 11  /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 12  /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 13  /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 14  /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 15  /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...

# %%
#Examples to just search for what we want from the catalog
expname_filter = ['QBOiExp1']
modeling_realm = 'atmos'
model_filter = 'GFDL-ESM4'
#ADD OR NOT# variable_id_filter = "ta"
ens_filter = "r1i1p1f1"
frequency = "mon"

# %%
cat = col.search(experiment_id=expname_filter,frequency="mon",modeling_realm=modeling_realm,
                 model=model_filter)


#OR SEARCH THE FOLLOWING WAY and build on the facets as needed
#cat = col.search(variable="hus")
#cat = col.search(experiment_id=expname_filter,frequency="mon",modeling_realm=modeling_realm,
#                 model=model_filter,variable=variable_id_filter)

# %%
cat.df
# Out:
#    project  institute      model experiment_id frequency modeling_realm  \
# 0     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 1     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 2     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 3     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 4     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 5     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 6     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 7     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 8     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 9     QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 10    QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 11    QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 12    QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 13    QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 14    QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
# 15    QBOi  NOAA-GFDL  GFDL-ESM4      QBOiExp1       mon          atmos
#
#    mip_table ensemble_member grid_label variable temporal subset version  \
# 0         na        r1i1p1f1         gn       ta   198001-198412      na
# 1         na        r1i1p1f1         gn       ta   198501-198912      na
# 2         na        r1i1p1f1         gn       ta   199001-199412      na
# 3         na        r1i1p1f1         gn       ta   199501-199912      na
# 4         na        r1i1p1f1         gn       ta   200001-200412      na
# 5         na        r1i1p1f1         gn       ta   200501-200912      na
# 6         na        r1i1p1f1         gn       ta   201001-201412      na
# 7         na        r1i1p1f1         gn       ta   201501-201912      na
# 8         na        r1i1p1f1         gn      hus   198001-198412      na
# 9         na        r1i1p1f1         gn      hus   198501-198912      na
# 10        na        r1i1p1f1         gn      hus   199001-199412      na
# 11        na        r1i1p1f1         gn      hus   199501-199912      na
# 12        na        r1i1p1f1         gn      hus   200001-200412      na
# 13        na        r1i1p1f1         gn      hus   200501-200912      na
# 14        na        r1i1p1f1         gn      hus   201001-201412      na
# 15        na        r1i1p1f1         gn      hus   201501-201912      na
#
#                                                  path
# 0   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 1   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 2   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 3   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 4   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 5   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 6   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 7   /nbhome/a1r/qboi/test1/QBOiExp1/mon/ta/ta_mon_...
# 8   /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 9   /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 10  /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 11  /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 12  /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 13  /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 14  /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...
# 15  /nbhome/a1r/qboi/test1/QBOiExp1/mon/hus/hus_mo...

# %%
#Remember ta is a 3D field

dset_dict = cat.to_dataset_dict(cdf_kwargs={'chunks': {'time':5}, 'decode_times': False})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'project.institute.model.experiment_id.modeling_realm.frequency'
# █

# %%
dset_dict
# Out:
# {'QBOi.NOAA-GFDL.GFDL-ESM4.QBOiExp1.atmos.mon': <xarray.Dataset>
#  Dimensions:          (bnds: 2, ensemble_member: 1, lat: 180, lon: 288, plev: 30, time: 480)
#  Coordinates:
#    * time             (time) float64 15.5 45.5 75.5 ... 1.456e+04 1.459e+04
#    * plev             (plev) float64 1e+05 9.25e+04 8.5e+04 ... 150.0 100.0 40.0
#    * lat              (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#    * lon              (lon) float64 0.625 1.875 3.125 4.375 ... 356.9 358.1 359.4
#    * ensemble_member  (ensemble_member) <U8 'r1i1p1f1'
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds        (time, bnds) float64 dask.array<chunksize=(5, 2), meta=np.ndarray>
#      lat_bnds         (lat, bnds) float64 dask.array<chunksize=(180, 2), meta=np.ndarray>
#      lon_bnds         (lon, bnds) float64 dask.array<chunksize=(288, 2), meta=np.ndarray>
#      hus              (ensemble_member, time, plev, lat, lon) float32 dask.array<chunksize=(1, 5, 30, 180, 288), meta=np.ndarray>
#      ta               (ensemble_member, time, plev, lat, lon) float32 dask.array<chunksize=(1, 5, 30, 180, 288), meta=np.ndarray>
#  Attributes:
#      table_info:              Creation Date:(11 Feb 2022) MD5:11bfc3a92ebd5260...
#      variant_label:           r1i1p1f1
#      activity_participation:  QBOi
#      forcing_index:           1
#      product:                 model-output
#      grid:                    Regridded from C96 cubed-sphere to 180x288 lat-lon
#      history:                 2022-11-23T18:08:54Z ;rewrote data to be consist...
#      realization_index:       1
#      source:                  ESM4 (description)
#      source_type:             AGCM
#      grid_label:              gr
#      initialization_index:    1
#      cmor_version:            3.6.1
#      realm:                   atmos
#      contact:                 gfdl.climate.model.info@noaa.gov
#      experiment_id:           QBOiExp1
#      tracking_id:             hdl:21.14100/34153e96-dfb1-4100-a8f0-7cbae9c43c5...
#      mip_era:                 QBOi
#      activity_id:             QBOi
#      experiment:              Climate run with zonal-mean tropical stratospher...
#      external_variables:      areacella
#      physics_index:           1
#      sub_experiment:          none
#      institution:             Geophisical Fluid Dynamic Laboratory, NOAA, Prin...
#      sub_experiment_id:       none
#      frequency:               mon
#      Conventions:             CF-1.8 QBOi
#      institution_id:          NOAA-GFDL
#      title:                   ESM4 output prepared for
#      further_info_url:        http://www.gfdl.noaa.gov
#      source_id:               ESM4
#      table_id:                mon
#      license:                 QBOi model data produced by NOAA-GFDL is license...
#      data_specs_version:      01.00.00
#      intake_esm_varname:      hus\nta
#      cohort:                  Registered
#      parent_experiment_id:    no parent
#      intake_esm_dataset_key:  QBOi.NOAA-GFDL.GFDL-ESM4.QBOiExp1.atmos.mon}

# %%
mytest_gfdl_esm4 = dset_dict["QBOi.NOAA-GFDL.GFDL-ESM4.QBOiExp1.atmos.mon"]

# %%
mytest_gfdl_esm4
# Out:
# <xarray.Dataset>
# Dimensions:          (bnds: 2, ensemble_member: 1, lat: 180, lon: 288, plev: 30, time: 480)
# Coordinates:
#   * time             (time) float64 15.5 45.5 75.5 ... 1.456e+04 1.459e+04
#   * plev             (plev) float64 1e+05 9.25e+04 8.5e+04 ... 150.0 100.0 40.0
#   * lat              (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 87.5 88.5 89.5
#   * lon              (lon) float64 0.625 1.875 3.125 4.375 ... 356.9 358.1 359.4
#   * ensemble_member  (ensemble_member) <U8 'r1i1p1f1'
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds        (time, bnds) float64 dask.array<chunksize=(5, 2), meta=np.ndarray>
#     lat_bnds         (lat, bnds) float64 dask.array<chunksize=(180, 2), meta=np.ndarray>
#     lon_bnds         (lon, bnds) float64 dask.array<chunksize=(288, 2), meta=np.ndarray>
#     hus              (ensemble_member, time, plev, lat, lon) float32 dask.array<chunksize=(1, 5, 30, 180, 288), meta=np.ndarray>
#     ta               (ensemble_member, time, plev, lat, lon) float32 dask.array<chunksize=(1, 5, 30, 180, 288), meta=np.ndarray>
# Attributes:
#     table_info:              Creation Date:(11 Feb 2022) MD5:11bfc3a92ebd5260...
#     variant_label:           r1i1p1f1
#     activity_participation:  QBOi
#     forcing_index:           1
#     product:                 model-output
#     grid:                    Regridded from C96 cubed-sphere to 180x288 lat-lon
#     history:                 2022-11-23T18:08:54Z ;rewrote data to be consist...
#     realization_index:       1
#     source:                  ESM4 (description)
#     source_type:             AGCM
#     grid_label:              gr
#     initialization_index:    1
#     cmor_version:            3.6.1
#     realm:                   atmos
#     contact:                 gfdl.climate.model.info@noaa.gov
#     experiment_id:           QBOiExp1
#     tracking_id:             hdl:21.14100/34153e96-dfb1-4100-a8f0-7cbae9c43c5...
#     mip_era:                 QBOi
#     activity_id:             QBOi
#     experiment:              Climate run with zonal-mean tropical stratospher...
#     external_variables:      areacella
#     physics_index:           1
#     sub_experiment:          none
#     institution:             Geophisical Fluid Dynamic Laboratory, NOAA, Prin...
#     sub_experiment_id:       none
#     frequency:               mon
#     Conventions:             CF-1.8 QBOi
#     institution_id:          NOAA-GFDL
#     title:                   ESM4 output prepared for
#     further_info_url:        http://www.gfdl.noaa.gov
#     source_id:               ESM4
#     table_id:                mon
#     license:                 QBOi model data produced by NOAA-GFDL is license...
#     data_specs_version:      01.00.00
#     intake_esm_varname:      hus\nta
#     cohort:                  Registered
#     parent_experiment_id:    no parent
#     intake_esm_dataset_key:  QBOi.NOAA-GFDL.GFDL-ESM4.QBOiExp1.atmos.mon
