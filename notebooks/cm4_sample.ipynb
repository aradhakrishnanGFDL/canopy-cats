# %% [markdown]
# This notebook was tested from a GFDL workstation.
# This notebook is an example of using catalog builder from a notebook to generate data catalogs, a.k.a intake-esm catalogs.
#
# How to get here?
#
# Login to your workstation at GFDL.
# module load miniforge
# conda activate catalogbuilder
# (For the above: Note that you can either install your own environment using the following or use an existing environment such as this: conda activate /nbhome/Aparna.Radhakrishnan/conda/envs/catalogbuilder)
#
# Alternatively (or the primary method)
#
# conda create -n catalogbuilder
# conda install catalogbuilder -c noaa-gfdl -n catalogbuilder
#
# Now, we do a couple of things to make sure your environment is available to jupyter-lab as a kernel.
#
# pip install ipykernel
# python -m ipykernel install --user --name=catalogbuilder
#
# Now, start a jupyter-lab session from GFDL workstation:
#
# jupyter-lab
#
# This will give you the URL to the jupyter-lab session running on your localhost. Paste the URL in your web-browser (or via TigerVNC). Paste the notebook cells from this notebook, or locate the notebook from the path where you have downloaded or cloned it via git. Go to Kernel->Change Kernel-> Choose intakebuilder.
#
# Run the notebook and see the results! Extend it and share it with us via a github issue.

# %%
import sys, os 
git_package_dir = '/home/a1r/git/forkCatalogBuilder-/'
sys.path.append(git_package_dir)

import catalogbuilder
from catalogbuilder.scripts import gen_intake_gfdl
######USER input begins########

#User provides the input directory for which a data catalog needs to be generated.

input_path = "/archive/John.Krasting/fre/FMS2024.02_OM5_20240724/CM4.5v01_om5b06_piC_noBLING/gfdl.ncrc5-intel23-prod-openmp/pp/"
#/archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pdclim1850F/gfdl.ncrc5-deploy-prod-openmp/pp/"

#USER inputs the output path. Based on the following setting, user can expect to see /home/a1r/mycatalog.csv and /home/a1r/mycatalog.json generated as output.

output_path = "/home/a1r/tests/mycatalog-jpk"
#NOTE: If your input_path does not look like the above in general, you will need to pass a --config which is custom 
#for your directory structure. See examples below.  
####END OF user input ##########

# %%
#This is an example call to run catalog builder using a yaml config file.
configyaml = os.path.join(git_package_dir, 'catalogbuilder/scripts/configs/config-example2.yml')
#input_path = "/archive/am5/am5/am5f3b1r0/c96L65_am5f3b1r0_pdclim1850F/gfdl.ncrc5-deploy-prod-openmp/pp"
#output_path = "sample-mdtf-catalog"

def create_catalog_from_config(input_path=input_path,output_path=output_path,configyaml=configyaml):
    csv, json = gen_intake_gfdl.create_catalog(input_path=input_path,output_path=output_path,config=configyaml)
    return(csv,json)

if __name__ == '__main__':
    create_catalog_from_config(input_path,output_path,configyaml)
# Out:
# input_path does not exist in config
# output_path does not exist in config
# headerlist : ['activity_id', 'institution_id', 'source_id', 'experiment_id', 'frequency', 'realm', 'table_id', 'member_id', 'grid_label', 'variable_id', 'time_range', 'chunk_freq', 'platform', 'dimensions', 'cell_methods', 'standard_name', 'path']
# output_path_template : ['NA', 'NA', 'source_id', 'NA', 'experiment_id', 'platform', 'custom_pp', 'realm', 'cell_methods', 'frequency', 'chunk_freq']
# output_file_template : ['realm', 'time_range', 'variable_id']
# We will use catalog builder catalogbuilder/cats/gfdl_template.json as your json schema
# input path:  /archive/John.Krasting/fre/FMS2024.02_OM5_20240724/CM4.5v01_om5b06_piC_noBLING/gfdl.ncrc5-intel23-prod-openmp/pp/  output path:  /home/a1r/tests/mycatalog-jpk
# Missing cols from metadata sources: ['activity_id', 'institution_id', 'table_id', 'member_id', 'grid_label', 'dimensions', 'standard_name']
# Skipping  .fregrid_remap_file_360_by_180.nc
# Skipping  .fregrid_remap_file_360_by_180.nc
# Skipping  .fregrid_remap_file_360_by_180.nc
# Skipping  .fregrid_remap_file_360_by_180.nc
# Skipping  .fregrid_remap_file_360_by_180.nc
# Skipping  .fregrid_remap_file_360_by_180.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  .fregrid_remap_file_144_by_90.nc
# Skipping  .fregrid_remap_file_144_by_90.nc
# Skipping  .fregrid_remap_file_144_by_90.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  .fregrid_remap_file_144_by_90.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  land_cubic.00010101-00051231.t_ref_max.tile3.nc
# Skipping  land_cubic.00010101-00051231.evap_land.tile1.nc
# Skipping  land_cubic.00010101-00051231.t_ref_min.tile3.nc
# Skipping  land_cubic.00010101-00051231.npp.tile1.nc
# Skipping  land_cubic.00010101-00051231.vegn_temp_max.tile3.nc
# Skipping  land_cubic.00010101-00051231.precip.tile1.nc
# Skipping  land_cubic.00010101-00051231.vegn_temp_min.tile3.nc
# Skipping  land_cubic.00010101-00051231.runf_soil.tile1.nc
# Skipping  land_cubic.00010101-00051231.evap_land.tile4.nc
# Skipping  land_cubic.00010101-00051231.snow_lake.tile1.nc
# Skipping  land_cubic.00010101-00051231.npp.tile4.nc
# Skipping  land_cubic.00010101-00051231.snow_soil.tile1.nc
# Skipping  land_cubic.00010101-00051231.precip.tile4.nc
# Skipping  land_cubic.00010101-00051231.soil_ice.tile1.nc
# Skipping  land_cubic.00010101-00051231.runf_soil.tile4.nc
# Skipping  land_cubic.00010101-00051231.soil_liq.tile1.nc
# Skipping  land_cubic.00010101-00051231.soil_liq.tile4.nc
# Skipping  land_cubic.00010101-00051231.t_ref_max.tile1.nc
# Skipping  land_cubic.00010101-00051231.t_ref_max.tile4.nc
# Skipping  land_cubic.00010101-00051231.t_ref_min.tile1.nc
# Skipping  land_cubic.00010101-00051231.snow_soil.tile3.nc
# Skipping  land_cubic.00010101-00051231.vegn_temp_max.tile1.nc
# Skipping  land_cubic.00010101-00051231.soil_ice.tile3.nc
# Skipping  land_cubic.00010101-00051231.vegn_temp_min.tile1.nc
# Skipping  land_cubic.00010101-00051231.t_ref_min.tile4.nc
# Skipping  land_cubic.00010101-00051231.evap_land.tile2.nc
# Skipping  land_cubic.00010101-00051231.vegn_temp_max.tile4.nc
# Skipping  land_cubic.00010101-00051231.npp.tile2.nc
# Skipping  land_cubic.00010101-00051231.vegn_temp_min.tile4.nc
# Skipping  land_cubic.00010101-00051231.precip.tile2.nc
# Skipping  land_cubic.00010101-00051231.evap_land.tile5.nc
# Skipping  land_cubic.00010101-00051231.runf_soil.tile2.nc
# Skipping  land_cubic.00010101-00051231.npp.tile5.nc
# Skipping  land_cubic.00010101-00051231.snow_lake.tile2.nc
# Skipping  land_cubic.00010101-00051231.precip.tile5.nc
# Skipping  land_cubic.00010101-00051231.snow_soil.tile2.nc
# Skipping  land_cubic.00010101-00051231.runf_soil.tile5.nc
# Skipping  land_cubic.00010101-00051231.soil_ice.tile2.nc
# Skipping  land_cubic.00010101-00051231.snow_lake.tile5.nc
# Skipping  land_cubic.00010101-00051231.soil_liq.tile2.nc
# Skipping  land_cubic.00010101-00051231.snow_soil.tile5.nc
# Skipping  land_cubic.00010101-00051231.t_ref_max.tile2.nc
# Skipping  land_cubic.00010101-00051231.soil_ice.tile5.nc
# Skipping  land_cubic.00010101-00051231.t_ref_min.tile2.nc
# Skipping  land_cubic.00010101-00051231.vegn_temp_max.tile2.nc
# Skipping  land_cubic.00010101-00051231.soil_liq.tile3.nc
# Skipping  land_cubic.00010101-00051231.vegn_temp_min.tile2.nc
# Skipping  land_cubic.00010101-00051231.soil_liq.tile5.nc
# Skipping  land_cubic.00010101-00051231.evap_land.tile3.nc
# Skipping  land_cubic.00010101-00051231.t_ref_max.tile5.nc
# Skipping  land_cubic.00010101-00051231.npp.tile3.nc
# Skipping  land_cubic.00010101-00051231.t_ref_min.tile5.nc
# Skipping  land_cubic.00010101-00051231.precip.tile3.nc
# Skipping  land_cubic.00010101-00051231.vegn_temp_max.tile5.nc
# Skipping  land_cubic.00010101-00051231.runf_soil.tile3.nc
# Skipping  land_cubic.00010101-00051231.vegn_temp_min.tile5.nc
# Skipping  land_cubic.00010101-00051231.snow_lake.tile3.nc
# Skipping  land_cubic.00010101-00051231.snow_lake.tile4.nc
# Skipping  land_cubic.00010101-00051231.evap_land.tile6.nc
# Skipping  land_cubic.00010101-00051231.snow_soil.tile4.nc
# Skipping  land_cubic.00010101-00051231.npp.tile6.nc
# Skipping  land_cubic.00010101-00051231.soil_ice.tile4.nc
# Skipping  land_cubic.00010101-00051231.precip.tile6.nc
# Skipping  land_cubic.00010101-00051231.runf_soil.tile6.nc
# Skipping  land_cubic.00010101-00051231.snow_lake.tile6.nc
# Skipping  land_cubic.00010101-00051231.snow_soil.tile6.nc
# Skipping  land_cubic.00010101-00051231.soil_ice.tile6.nc
# Skipping  land_cubic.00010101-00051231.soil_liq.tile6.nc
# Skipping  land_cubic.00010101-00051231.t_ref_max.tile6.nc
# Skipping  land_cubic.00010101-00051231.t_ref_min.tile6.nc
# Skipping  land_cubic.00010101-00051231.vegn_temp_max.tile6.nc
# Skipping  land_cubic.00010101-00051231.vegn_temp_min.tile6.nc
# Skipping  land_cubic.00060101-00101231.evap_land.tile1.nc
# Skipping  land_cubic.00060101-00101231.npp.tile1.nc
# Skipping  land_cubic.00060101-00101231.precip.tile1.nc
# Skipping  land_cubic.00060101-00101231.runf_soil.tile1.nc
# Skipping  land_cubic.00060101-00101231.snow_lake.tile1.nc
# Skipping  land_cubic.00060101-00101231.snow_soil.tile1.nc
# Skipping  land_cubic.00060101-00101231.soil_ice.tile1.nc
# Skipping  land_cubic.00060101-00101231.soil_liq.tile1.nc
# Skipping  land_cubic.00060101-00101231.t_ref_max.tile1.nc
# Skipping  land_cubic.00060101-00101231.t_ref_min.tile1.nc
# Skipping  land_cubic.00060101-00101231.vegn_temp_max.tile1.nc
# Skipping  land_cubic.00060101-00101231.vegn_temp_min.tile1.nc
# Skipping  land_cubic.00060101-00101231.evap_land.tile2.nc
# Skipping  land_cubic.00060101-00101231.npp.tile2.nc
# Skipping  land_cubic.00060101-00101231.precip.tile2.nc
# Skipping  land_cubic.00060101-00101231.runf_soil.tile2.nc
# Skipping  land_cubic.00060101-00101231.snow_lake.tile2.nc
# Skipping  land_cubic.00060101-00101231.snow_soil.tile2.nc
# Skipping  land_cubic.00060101-00101231.soil_ice.tile2.nc
# Skipping  land_cubic.00060101-00101231.soil_liq.tile2.nc
# Skipping  land_cubic.00060101-00101231.t_ref_max.tile2.nc
# Skipping  land_cubic.00060101-00101231.t_ref_min.tile2.nc
# Skipping  land_cubic.00060101-00101231.vegn_temp_max.tile2.nc
# Skipping  land_cubic.00060101-00101231.vegn_temp_min.tile2.nc
# Skipping  land_cubic.00060101-00101231.evap_land.tile3.nc
# Skipping  land_cubic.00060101-00101231.npp.tile3.nc
# Skipping  land_cubic.00060101-00101231.precip.tile3.nc
# Skipping  land_cubic.00060101-00101231.runf_soil.tile3.nc
# Skipping  land_cubic.00060101-00101231.snow_lake.tile3.nc
# Skipping  land_cubic.00060101-00101231.snow_soil.tile3.nc
# Skipping  land_cubic.00060101-00101231.soil_ice.tile3.nc
# Skipping  land_cubic.00060101-00101231.soil_liq.tile3.nc
# Skipping  land_cubic.00060101-00101231.t_ref_max.tile3.nc
# Skipping  land_cubic.00060101-00101231.t_ref_min.tile3.nc
# Skipping  land_cubic.00060101-00101231.vegn_temp_max.tile3.nc
# Skipping  land_cubic.00060101-00101231.vegn_temp_min.tile3.nc
# Skipping  land_cubic.00060101-00101231.evap_land.tile4.nc
# Skipping  land_cubic.00060101-00101231.npp.tile4.nc
# Skipping  land_cubic.00060101-00101231.precip.tile4.nc
# Skipping  land_cubic.00060101-00101231.runf_soil.tile4.nc
# Skipping  land_cubic.00060101-00101231.snow_lake.tile4.nc
# Skipping  land_cubic.00060101-00101231.snow_soil.tile4.nc
# Skipping  land_cubic.00060101-00101231.soil_ice.tile4.nc
# Skipping  land_cubic.00060101-00101231.soil_liq.tile4.nc
# Skipping  land_cubic.00060101-00101231.t_ref_max.tile4.nc
# Skipping  land_cubic.00060101-00101231.t_ref_min.tile4.nc
# Skipping  land_cubic.00060101-00101231.vegn_temp_max.tile4.nc
# Skipping  land_cubic.00060101-00101231.vegn_temp_min.tile4.nc
# Skipping  land_cubic.00060101-00101231.evap_land.tile5.nc
# Skipping  land_cubic.00060101-00101231.npp.tile5.nc
# Skipping  land_cubic.00060101-00101231.precip.tile5.nc
# Skipping  land_cubic.00060101-00101231.runf_soil.tile5.nc
# Skipping  land_cubic.00060101-00101231.snow_lake.tile5.nc
# Skipping  land_cubic.00060101-00101231.snow_soil.tile5.nc
# Skipping  land_cubic.00060101-00101231.soil_ice.tile5.nc
# Skipping  land_cubic.00060101-00101231.soil_liq.tile5.nc
# Skipping  land_cubic.00060101-00101231.t_ref_max.tile5.nc
# Skipping  land_cubic.00060101-00101231.t_ref_min.tile5.nc
# Skipping  land_cubic.00060101-00101231.vegn_temp_max.tile5.nc
# Skipping  land_cubic.00060101-00101231.vegn_temp_min.tile5.nc
# Skipping  land_cubic.00060101-00101231.evap_land.tile6.nc
# Skipping  land_cubic.00060101-00101231.npp.tile6.nc
# Skipping  land_cubic.00060101-00101231.precip.tile6.nc
# Skipping  land_cubic.00060101-00101231.runf_soil.tile6.nc
# Skipping  land_cubic.00060101-00101231.snow_lake.tile6.nc
# Skipping  land_cubic.00060101-00101231.snow_soil.tile6.nc
# Skipping  land_cubic.00060101-00101231.soil_ice.tile6.nc
# Skipping  land_cubic.00060101-00101231.soil_liq.tile6.nc
# Skipping  land_cubic.00060101-00101231.t_ref_max.tile6.nc
# Skipping  land_cubic.00060101-00101231.t_ref_min.tile6.nc
# Skipping  land_cubic.00060101-00101231.vegn_temp_max.tile6.nc
# Skipping  land_cubic.00060101-00101231.vegn_temp_min.tile6.nc
# Skipping  land_cubic.00110101-00151231.evap_land.tile1.nc
# Skipping  land_cubic.00110101-00151231.npp.tile1.nc
# Skipping  land_cubic.00110101-00151231.precip.tile1.nc
# Skipping  land_cubic.00110101-00151231.runf_soil.tile1.nc
# Skipping  land_cubic.00110101-00151231.snow_lake.tile1.nc
# Skipping  land_cubic.00110101-00151231.snow_soil.tile1.nc
# Skipping  land_cubic.00110101-00151231.soil_ice.tile1.nc
# Skipping  land_cubic.00110101-00151231.soil_liq.tile1.nc
# Skipping  land_cubic.00110101-00151231.t_ref_max.tile1.nc
# Skipping  land_cubic.00110101-00151231.t_ref_min.tile1.nc
# Skipping  land_cubic.00110101-00151231.vegn_temp_max.tile1.nc
# Skipping  land_cubic.00110101-00151231.vegn_temp_min.tile1.nc
# Skipping  land_cubic.00110101-00151231.evap_land.tile2.nc
# Skipping  land_cubic.00110101-00151231.npp.tile2.nc
# Skipping  land_cubic.00110101-00151231.precip.tile2.nc
# Skipping  land_cubic.00110101-00151231.runf_soil.tile2.nc
# Skipping  land_cubic.00110101-00151231.snow_lake.tile2.nc
# Skipping  land_cubic.00110101-00151231.snow_soil.tile2.nc
# Skipping  land_cubic.00110101-00151231.soil_ice.tile2.nc
# Skipping  land_cubic.00110101-00151231.soil_liq.tile2.nc
# Skipping  land_cubic.00110101-00151231.t_ref_max.tile2.nc
# Skipping  land_cubic.00110101-00151231.t_ref_min.tile2.nc
# Skipping  land_cubic.00110101-00151231.vegn_temp_max.tile2.nc
# Skipping  land_cubic.00110101-00151231.vegn_temp_min.tile2.nc
# Skipping  land_cubic.00110101-00151231.evap_land.tile3.nc
# Skipping  land_cubic.00110101-00151231.npp.tile3.nc
# Skipping  land_cubic.00110101-00151231.precip.tile3.nc
# Skipping  land_cubic.00110101-00151231.runf_soil.tile3.nc
# Skipping  land_cubic.00110101-00151231.snow_lake.tile3.nc
# Skipping  land_cubic.00110101-00151231.snow_soil.tile3.nc
# Skipping  land_cubic.00110101-00151231.soil_ice.tile3.nc
# Skipping  land_cubic.00110101-00151231.soil_liq.tile3.nc
# Skipping  land_cubic.00110101-00151231.t_ref_max.tile3.nc
# Skipping  land_cubic.00110101-00151231.t_ref_min.tile3.nc
# Skipping  land_cubic.00110101-00151231.vegn_temp_max.tile3.nc
# Skipping  land_cubic.00110101-00151231.vegn_temp_min.tile3.nc
# Skipping  land_cubic.00110101-00151231.evap_land.tile4.nc
# Skipping  land_cubic.00110101-00151231.npp.tile4.nc
# Skipping  land_cubic.00110101-00151231.precip.tile4.nc
# Skipping  land_cubic.00110101-00151231.runf_soil.tile4.nc
# Skipping  land_cubic.00110101-00151231.snow_lake.tile4.nc
# Skipping  land_cubic.00110101-00151231.snow_soil.tile4.nc
# Skipping  land_cubic.00110101-00151231.soil_ice.tile4.nc
# Skipping  land_cubic.00110101-00151231.soil_liq.tile4.nc
# Skipping  land_cubic.00110101-00151231.t_ref_max.tile4.nc
# Skipping  land_cubic.00110101-00151231.t_ref_min.tile4.nc
# Skipping  land_cubic.00110101-00151231.vegn_temp_max.tile4.nc
# Skipping  land_cubic.00110101-00151231.vegn_temp_min.tile4.nc
# Skipping  land_cubic.00110101-00151231.evap_land.tile5.nc
# Skipping  land_cubic.00110101-00151231.npp.tile5.nc
# Skipping  land_cubic.00110101-00151231.precip.tile5.nc
# Skipping  land_cubic.00110101-00151231.runf_soil.tile5.nc
# Skipping  land_cubic.00110101-00151231.snow_lake.tile5.nc
# Skipping  land_cubic.00110101-00151231.snow_soil.tile5.nc
# Skipping  land_cubic.00110101-00151231.soil_ice.tile5.nc
# Skipping  land_cubic.00110101-00151231.soil_liq.tile5.nc
# Skipping  land_cubic.00110101-00151231.t_ref_max.tile5.nc
# Skipping  land_cubic.00110101-00151231.t_ref_min.tile5.nc
# Skipping  land_cubic.00110101-00151231.vegn_temp_max.tile5.nc
# Skipping  land_cubic.00110101-00151231.vegn_temp_min.tile5.nc
# Skipping  land_cubic.00110101-00151231.evap_land.tile6.nc
# Skipping  land_cubic.00110101-00151231.npp.tile6.nc
# Skipping  land_cubic.00110101-00151231.precip.tile6.nc
# Skipping  land_cubic.00110101-00151231.runf_soil.tile6.nc
# Skipping  land_cubic.00110101-00151231.snow_lake.tile6.nc
# Skipping  land_cubic.00110101-00151231.snow_soil.tile6.nc
# Skipping  land_cubic.00110101-00151231.soil_ice.tile6.nc
# Skipping  land_cubic.00110101-00151231.soil_liq.tile6.nc
# Skipping  land_cubic.00110101-00151231.t_ref_max.tile6.nc
# Skipping  land_cubic.00110101-00151231.t_ref_min.tile6.nc
# Skipping  land_cubic.00110101-00151231.vegn_temp_max.tile6.nc
# Skipping  land_cubic.00110101-00151231.vegn_temp_min.tile6.nc
# Skipping  land_cubic.00160101-00201231.evap_land.tile1.nc
# Skipping  land_cubic.00160101-00201231.npp.tile1.nc
# Skipping  land_cubic.00160101-00201231.precip.tile1.nc
# Skipping  land_cubic.00160101-00201231.runf_soil.tile1.nc
# Skipping  land_cubic.00160101-00201231.snow_lake.tile1.nc
# Skipping  land_cubic.00160101-00201231.snow_soil.tile1.nc
# Skipping  land_cubic.00160101-00201231.soil_ice.tile1.nc
# Skipping  land_cubic.00160101-00201231.soil_liq.tile1.nc
# Skipping  land_cubic.00160101-00201231.t_ref_max.tile1.nc
# Skipping  land_cubic.00160101-00201231.t_ref_min.tile1.nc
# Skipping  land_cubic.00160101-00201231.vegn_temp_max.tile1.nc
# Skipping  land_cubic.00160101-00201231.vegn_temp_min.tile1.nc
# Skipping  land_cubic.00160101-00201231.evap_land.tile2.nc
# Skipping  land_cubic.00160101-00201231.npp.tile2.nc
# Skipping  land_cubic.00160101-00201231.precip.tile2.nc
# Skipping  land_cubic.00160101-00201231.runf_soil.tile2.nc
# Skipping  land_cubic.00160101-00201231.snow_lake.tile2.nc
# Skipping  land_cubic.00160101-00201231.snow_soil.tile2.nc
# Skipping  land_cubic.00160101-00201231.soil_ice.tile2.nc
# Skipping  land_cubic.00160101-00201231.soil_liq.tile2.nc
# Skipping  land_cubic.00160101-00201231.t_ref_max.tile2.nc
# Skipping  land_cubic.00160101-00201231.t_ref_min.tile2.nc
# Skipping  land_cubic.00160101-00201231.vegn_temp_max.tile2.nc
# Skipping  land_cubic.00160101-00201231.vegn_temp_min.tile2.nc
# Skipping  land_cubic.00160101-00201231.evap_land.tile3.nc
# Skipping  land_cubic.00160101-00201231.npp.tile3.nc
# Skipping  land_cubic.00160101-00201231.precip.tile3.nc
# Skipping  land_cubic.00160101-00201231.runf_soil.tile3.nc
# Skipping  land_cubic.00160101-00201231.snow_lake.tile3.nc
# Skipping  land_cubic.00160101-00201231.snow_soil.tile3.nc
# Skipping  land_cubic.00160101-00201231.soil_ice.tile3.nc
# Skipping  land_cubic.00160101-00201231.soil_liq.tile3.nc
# Skipping  land_cubic.00160101-00201231.t_ref_max.tile3.nc
# Skipping  land_cubic.00160101-00201231.t_ref_min.tile3.nc
# Skipping  land_cubic.00160101-00201231.vegn_temp_max.tile3.nc
# Skipping  land_cubic.00160101-00201231.vegn_temp_min.tile3.nc
# Skipping  land_cubic.00160101-00201231.evap_land.tile4.nc
# Skipping  land_cubic.00160101-00201231.npp.tile4.nc
# Skipping  land_cubic.00160101-00201231.precip.tile4.nc
# Skipping  land_cubic.00160101-00201231.runf_soil.tile4.nc
# Skipping  land_cubic.00160101-00201231.snow_lake.tile4.nc
# Skipping  land_cubic.00160101-00201231.snow_soil.tile4.nc
# Skipping  land_cubic.00160101-00201231.soil_ice.tile4.nc
# Skipping  land_cubic.00160101-00201231.soil_liq.tile4.nc
# Skipping  land_cubic.00160101-00201231.t_ref_max.tile4.nc
# Skipping  land_cubic.00160101-00201231.t_ref_min.tile4.nc
# Skipping  land_cubic.00160101-00201231.vegn_temp_max.tile4.nc
# Skipping  land_cubic.00160101-00201231.vegn_temp_min.tile4.nc
# Skipping  land_cubic.00160101-00201231.evap_land.tile5.nc
# Skipping  land_cubic.00160101-00201231.npp.tile5.nc
# Skipping  land_cubic.00160101-00201231.precip.tile5.nc
# Skipping  land_cubic.00160101-00201231.runf_soil.tile5.nc
# Skipping  land_cubic.00160101-00201231.snow_lake.tile5.nc
# Skipping  land_cubic.00160101-00201231.snow_soil.tile5.nc
# Skipping  land_cubic.00160101-00201231.soil_ice.tile5.nc
# Skipping  land_cubic.00160101-00201231.soil_liq.tile5.nc
# Skipping  land_cubic.00160101-00201231.t_ref_max.tile5.nc
# Skipping  land_cubic.00160101-00201231.t_ref_min.tile5.nc
# Skipping  land_cubic.00160101-00201231.vegn_temp_max.tile5.nc
# Skipping  land_cubic.00160101-00201231.vegn_temp_min.tile5.nc
# Skipping  land_cubic.00160101-00201231.evap_land.tile6.nc
# Skipping  land_cubic.00160101-00201231.npp.tile6.nc
# Skipping  land_cubic.00160101-00201231.precip.tile6.nc
# Skipping  land_cubic.00160101-00201231.runf_soil.tile6.nc
# Skipping  land_cubic.00160101-00201231.snow_lake.tile6.nc
# Skipping  land_cubic.00160101-00201231.snow_soil.tile6.nc
# Skipping  land_cubic.00160101-00201231.soil_ice.tile6.nc
# Skipping  land_cubic.00160101-00201231.soil_liq.tile6.nc
# Skipping  land_cubic.00160101-00201231.t_ref_max.tile6.nc
# Skipping  land_cubic.00160101-00201231.t_ref_min.tile6.nc
# Skipping  land_cubic.00160101-00201231.vegn_temp_max.tile6.nc
# Skipping  land_cubic.00160101-00201231.vegn_temp_min.tile6.nc
# Skipping  land_cubic.00210101-00251231.evap_land.tile1.nc
# Skipping  land_cubic.00210101-00251231.npp.tile1.nc
# Skipping  land_cubic.00210101-00251231.precip.tile1.nc
# Skipping  land_cubic.00210101-00251231.runf_soil.tile1.nc
# Skipping  land_cubic.00210101-00251231.snow_lake.tile1.nc
# Skipping  land_cubic.00210101-00251231.snow_soil.tile1.nc
# Skipping  land_cubic.00210101-00251231.soil_ice.tile1.nc
# Skipping  land_cubic.00210101-00251231.soil_liq.tile1.nc
# Skipping  land_cubic.00210101-00251231.t_ref_max.tile1.nc
# Skipping  land_cubic.00210101-00251231.t_ref_min.tile1.nc
# Skipping  land_cubic.00210101-00251231.vegn_temp_max.tile1.nc
# Skipping  land_cubic.00210101-00251231.vegn_temp_min.tile1.nc
# Skipping  land_cubic.00210101-00251231.evap_land.tile2.nc
# Skipping  land_cubic.00210101-00251231.npp.tile2.nc
# Skipping  land_cubic.00210101-00251231.precip.tile2.nc
# Skipping  land_cubic.00210101-00251231.runf_soil.tile2.nc
# Skipping  land_cubic.00210101-00251231.snow_lake.tile2.nc
# Skipping  land_cubic.00210101-00251231.snow_soil.tile2.nc
# Skipping  land_cubic.00210101-00251231.soil_ice.tile2.nc
# Skipping  land_cubic.00210101-00251231.soil_liq.tile2.nc
# Skipping  land_cubic.00210101-00251231.t_ref_max.tile2.nc
# Skipping  land_cubic.00210101-00251231.t_ref_min.tile2.nc
# Skipping  land_cubic.00210101-00251231.vegn_temp_max.tile2.nc
# Skipping  land_cubic.00210101-00251231.vegn_temp_min.tile2.nc
# Skipping  land_cubic.00210101-00251231.evap_land.tile3.nc
# Skipping  land_cubic.00210101-00251231.npp.tile3.nc
# Skipping  land_cubic.00210101-00251231.precip.tile3.nc
# Skipping  land_cubic.00210101-00251231.runf_soil.tile3.nc
# Skipping  land_cubic.00210101-00251231.snow_lake.tile3.nc
# Skipping  land_cubic.00210101-00251231.snow_soil.tile3.nc
# Skipping  land_cubic.00210101-00251231.soil_ice.tile3.nc
# Skipping  land_cubic.00210101-00251231.soil_liq.tile3.nc
# Skipping  land_cubic.00210101-00251231.t_ref_max.tile3.nc
# Skipping  land_cubic.00210101-00251231.t_ref_min.tile3.nc
# Skipping  land_cubic.00210101-00251231.vegn_temp_max.tile3.nc
# Skipping  land_cubic.00210101-00251231.vegn_temp_min.tile3.nc
# Skipping  land_cubic.00210101-00251231.evap_land.tile4.nc
# Skipping  land_cubic.00210101-00251231.npp.tile4.nc
# Skipping  land_cubic.00210101-00251231.precip.tile4.nc
# Skipping  land_cubic.00210101-00251231.runf_soil.tile4.nc
# Skipping  land_cubic.00210101-00251231.snow_lake.tile4.nc
# Skipping  land_cubic.00210101-00251231.snow_soil.tile4.nc
# Skipping  land_cubic.00210101-00251231.soil_ice.tile4.nc
# Skipping  land_cubic.00210101-00251231.soil_liq.tile4.nc
# Skipping  land_cubic.00210101-00251231.t_ref_max.tile4.nc
# Skipping  land_cubic.00210101-00251231.t_ref_min.tile4.nc
# Skipping  land_cubic.00210101-00251231.vegn_temp_max.tile4.nc
# Skipping  land_cubic.00210101-00251231.vegn_temp_min.tile4.nc
# Skipping  land_cubic.00210101-00251231.evap_land.tile5.nc
# Skipping  land_cubic.00210101-00251231.npp.tile5.nc
# Skipping  land_cubic.00210101-00251231.precip.tile5.nc
# Skipping  land_cubic.00210101-00251231.runf_soil.tile5.nc
# Skipping  land_cubic.00210101-00251231.snow_lake.tile5.nc
# Skipping  land_cubic.00210101-00251231.snow_soil.tile5.nc
# Skipping  land_cubic.00210101-00251231.soil_ice.tile5.nc
# Skipping  land_cubic.00210101-00251231.soil_liq.tile5.nc
# Skipping  land_cubic.00210101-00251231.t_ref_max.tile5.nc
# Skipping  land_cubic.00210101-00251231.t_ref_min.tile5.nc
# Skipping  land_cubic.00210101-00251231.vegn_temp_max.tile5.nc
# Skipping  land_cubic.00210101-00251231.vegn_temp_min.tile5.nc
# Skipping  land_cubic.00210101-00251231.evap_land.tile6.nc
# Skipping  land_cubic.00210101-00251231.npp.tile6.nc
# Skipping  land_cubic.00210101-00251231.precip.tile6.nc
# Skipping  land_cubic.00210101-00251231.runf_soil.tile6.nc
# Skipping  land_cubic.00210101-00251231.snow_lake.tile6.nc
# Skipping  land_cubic.00210101-00251231.snow_soil.tile6.nc
# Skipping  land_cubic.00210101-00251231.soil_ice.tile6.nc
# Skipping  land_cubic.00210101-00251231.soil_liq.tile6.nc
# Skipping  land_cubic.00210101-00251231.t_ref_max.tile6.nc
# Skipping  land_cubic.00210101-00251231.t_ref_min.tile6.nc
# Skipping  land_cubic.00210101-00251231.vegn_temp_max.tile6.nc
# Skipping  land_cubic.00210101-00251231.vegn_temp_min.tile6.nc
# Skipping  land_cubic.00260101-00301231.evap_land.tile1.nc
# Skipping  land_cubic.00260101-00301231.npp.tile1.nc
# Skipping  land_cubic.00260101-00301231.precip.tile1.nc
# Skipping  land_cubic.00260101-00301231.runf_soil.tile1.nc
# Skipping  land_cubic.00260101-00301231.snow_lake.tile1.nc
# Skipping  land_cubic.00260101-00301231.snow_soil.tile1.nc
# Skipping  land_cubic.00260101-00301231.soil_ice.tile1.nc
# Skipping  land_cubic.00260101-00301231.soil_liq.tile1.nc
# Skipping  land_cubic.00260101-00301231.t_ref_max.tile1.nc
# Skipping  land_cubic.00260101-00301231.t_ref_min.tile1.nc
# Skipping  land_cubic.00260101-00301231.vegn_temp_max.tile1.nc
# Skipping  land_cubic.00260101-00301231.vegn_temp_min.tile1.nc
# Skipping  land_cubic.00260101-00301231.evap_land.tile2.nc
# Skipping  land_cubic.00260101-00301231.npp.tile2.nc
# Skipping  land_cubic.00260101-00301231.precip.tile2.nc
# Skipping  land_cubic.00260101-00301231.runf_soil.tile2.nc
# Skipping  land_cubic.00260101-00301231.snow_lake.tile2.nc
# Skipping  land_cubic.00260101-00301231.snow_soil.tile2.nc
# Skipping  land_cubic.00260101-00301231.soil_ice.tile2.nc
# Skipping  land_cubic.00260101-00301231.soil_liq.tile2.nc
# Skipping  land_cubic.00260101-00301231.t_ref_max.tile2.nc
# Skipping  land_cubic.00260101-00301231.t_ref_min.tile2.nc
# Skipping  land_cubic.00260101-00301231.vegn_temp_max.tile2.nc
# Skipping  land_cubic.00260101-00301231.vegn_temp_min.tile2.nc
# Skipping  land_cubic.00260101-00301231.evap_land.tile3.nc
# Skipping  land_cubic.00260101-00301231.npp.tile3.nc
# Skipping  land_cubic.00260101-00301231.precip.tile3.nc
# Skipping  land_cubic.00260101-00301231.runf_soil.tile3.nc
# Skipping  land_cubic.00260101-00301231.snow_lake.tile3.nc
# Skipping  land_cubic.00260101-00301231.snow_soil.tile3.nc
# Skipping  land_cubic.00260101-00301231.soil_ice.tile3.nc
# Skipping  land_cubic.00260101-00301231.soil_liq.tile3.nc
# Skipping  land_cubic.00260101-00301231.t_ref_max.tile3.nc
# Skipping  land_cubic.00260101-00301231.t_ref_min.tile3.nc
# Skipping  land_cubic.00260101-00301231.vegn_temp_max.tile3.nc
# Skipping  land_cubic.00260101-00301231.vegn_temp_min.tile3.nc
# Skipping  land_cubic.00260101-00301231.evap_land.tile4.nc
# Skipping  land_cubic.00260101-00301231.npp.tile4.nc
# Skipping  land_cubic.00260101-00301231.precip.tile4.nc
# Skipping  land_cubic.00260101-00301231.runf_soil.tile4.nc
# Skipping  land_cubic.00260101-00301231.snow_lake.tile4.nc
# Skipping  land_cubic.00260101-00301231.snow_soil.tile4.nc
# Skipping  land_cubic.00260101-00301231.soil_ice.tile4.nc
# Skipping  land_cubic.00260101-00301231.soil_liq.tile4.nc
# Skipping  land_cubic.00260101-00301231.t_ref_max.tile4.nc
# Skipping  land_cubic.00260101-00301231.t_ref_min.tile4.nc
# Skipping  land_cubic.00260101-00301231.vegn_temp_max.tile4.nc
# Skipping  land_cubic.00260101-00301231.vegn_temp_min.tile4.nc
# Skipping  land_cubic.00260101-00301231.evap_land.tile5.nc
# Skipping  land_cubic.00260101-00301231.npp.tile5.nc
# Skipping  land_cubic.00260101-00301231.precip.tile5.nc
# Skipping  land_cubic.00260101-00301231.runf_soil.tile5.nc
# Skipping  land_cubic.00260101-00301231.snow_lake.tile5.nc
# Skipping  land_cubic.00260101-00301231.snow_soil.tile5.nc
# Skipping  land_cubic.00260101-00301231.soil_ice.tile5.nc
# Skipping  land_cubic.00260101-00301231.soil_liq.tile5.nc
# Skipping  land_cubic.00260101-00301231.t_ref_max.tile5.nc
# Skipping  land_cubic.00260101-00301231.t_ref_min.tile5.nc
# Skipping  land_cubic.00260101-00301231.vegn_temp_max.tile5.nc
# Skipping  land_cubic.00260101-00301231.vegn_temp_min.tile5.nc
# Skipping  land_cubic.00260101-00301231.evap_land.tile6.nc
# Skipping  land_cubic.00260101-00301231.npp.tile6.nc
# Skipping  land_cubic.00260101-00301231.precip.tile6.nc
# Skipping  land_cubic.00260101-00301231.runf_soil.tile6.nc
# Skipping  land_cubic.00260101-00301231.snow_lake.tile6.nc
# Skipping  land_cubic.00260101-00301231.snow_soil.tile6.nc
# Skipping  land_cubic.00260101-00301231.soil_ice.tile6.nc
# Skipping  land_cubic.00260101-00301231.soil_liq.tile6.nc
# Skipping  land_cubic.00260101-00301231.t_ref_max.tile6.nc
# Skipping  land_cubic.00260101-00301231.t_ref_min.tile6.nc
# Skipping  land_cubic.00260101-00301231.vegn_temp_max.tile6.nc
# Skipping  land_cubic.00260101-00301231.vegn_temp_min.tile6.nc
# Skipping  land_cubic.00310101-00351231.evap_land.tile1.nc
# Skipping  land_cubic.00310101-00351231.npp.tile1.nc
# Skipping  land_cubic.00310101-00351231.precip.tile1.nc
# Skipping  land_cubic.00310101-00351231.runf_soil.tile1.nc
# Skipping  land_cubic.00310101-00351231.snow_lake.tile1.nc
# Skipping  land_cubic.00310101-00351231.snow_soil.tile1.nc
# Skipping  land_cubic.00310101-00351231.soil_ice.tile1.nc
# Skipping  land_cubic.00310101-00351231.soil_liq.tile1.nc
# Skipping  land_cubic.00310101-00351231.t_ref_max.tile1.nc
# Skipping  land_cubic.00310101-00351231.t_ref_min.tile1.nc
# Skipping  land_cubic.00310101-00351231.vegn_temp_max.tile1.nc
# Skipping  land_cubic.00310101-00351231.vegn_temp_min.tile1.nc
# Skipping  land_cubic.00310101-00351231.evap_land.tile2.nc
# Skipping  land_cubic.00310101-00351231.npp.tile2.nc
# Skipping  land_cubic.00310101-00351231.precip.tile2.nc
# Skipping  land_cubic.00310101-00351231.runf_soil.tile2.nc
# Skipping  land_cubic.00310101-00351231.snow_lake.tile2.nc
# Skipping  land_cubic.00310101-00351231.snow_soil.tile2.nc
# Skipping  land_cubic.00310101-00351231.soil_ice.tile2.nc
# Skipping  land_cubic.00310101-00351231.soil_liq.tile2.nc
# Skipping  land_cubic.00310101-00351231.t_ref_max.tile2.nc
# Skipping  land_cubic.00310101-00351231.t_ref_min.tile2.nc
# Skipping  land_cubic.00310101-00351231.vegn_temp_max.tile2.nc
# Skipping  land_cubic.00310101-00351231.vegn_temp_min.tile2.nc
# Skipping  land_cubic.00310101-00351231.evap_land.tile3.nc
# Skipping  land_cubic.00310101-00351231.npp.tile3.nc
# Skipping  land_cubic.00310101-00351231.precip.tile3.nc
# Skipping  land_cubic.00310101-00351231.runf_soil.tile3.nc
# Skipping  land_cubic.00310101-00351231.snow_lake.tile3.nc
# Skipping  land_cubic.00310101-00351231.snow_soil.tile3.nc
# Skipping  land_cubic.00310101-00351231.soil_ice.tile3.nc
# Skipping  land_cubic.00310101-00351231.soil_liq.tile3.nc
# Skipping  land_cubic.00310101-00351231.t_ref_max.tile3.nc
# Skipping  land_cubic.00310101-00351231.t_ref_min.tile3.nc
# Skipping  land_cubic.00310101-00351231.vegn_temp_max.tile3.nc
# Skipping  land_cubic.00310101-00351231.vegn_temp_min.tile3.nc
# Skipping  land_cubic.00310101-00351231.evap_land.tile4.nc
# Skipping  land_cubic.00310101-00351231.npp.tile4.nc
# Skipping  land_cubic.00310101-00351231.precip.tile4.nc
# Skipping  land_cubic.00310101-00351231.runf_soil.tile4.nc
# Skipping  land_cubic.00310101-00351231.snow_lake.tile4.nc
# Skipping  land_cubic.00310101-00351231.snow_soil.tile4.nc
# Skipping  land_cubic.00310101-00351231.soil_ice.tile4.nc
# Skipping  land_cubic.00310101-00351231.soil_liq.tile4.nc
# Skipping  land_cubic.00310101-00351231.t_ref_max.tile4.nc
# Skipping  land_cubic.00310101-00351231.t_ref_min.tile4.nc
# Skipping  land_cubic.00310101-00351231.vegn_temp_max.tile4.nc
# Skipping  land_cubic.00310101-00351231.vegn_temp_min.tile4.nc
# Skipping  land_cubic.00310101-00351231.evap_land.tile5.nc
# Skipping  land_cubic.00310101-00351231.npp.tile5.nc
# Skipping  land_cubic.00310101-00351231.precip.tile5.nc
# Skipping  land_cubic.00310101-00351231.runf_soil.tile5.nc
# Skipping  land_cubic.00310101-00351231.snow_lake.tile5.nc
# Skipping  land_cubic.00310101-00351231.snow_soil.tile5.nc
# Skipping  land_cubic.00310101-00351231.soil_ice.tile5.nc
# Skipping  land_cubic.00310101-00351231.soil_liq.tile5.nc
# Skipping  land_cubic.00310101-00351231.t_ref_max.tile5.nc
# Skipping  land_cubic.00310101-00351231.t_ref_min.tile5.nc
# Skipping  land_cubic.00310101-00351231.vegn_temp_max.tile5.nc
# Skipping  land_cubic.00310101-00351231.vegn_temp_min.tile5.nc
# Skipping  land_cubic.00310101-00351231.evap_land.tile6.nc
# Skipping  land_cubic.00310101-00351231.npp.tile6.nc
# Skipping  land_cubic.00310101-00351231.precip.tile6.nc
# Skipping  land_cubic.00310101-00351231.runf_soil.tile6.nc
# Skipping  land_cubic.00310101-00351231.snow_lake.tile6.nc
# Skipping  land_cubic.00310101-00351231.snow_soil.tile6.nc
# Skipping  land_cubic.00310101-00351231.soil_ice.tile6.nc
# Skipping  land_cubic.00310101-00351231.soil_liq.tile6.nc
# Skipping  land_cubic.00310101-00351231.t_ref_max.tile6.nc
# Skipping  land_cubic.00310101-00351231.t_ref_min.tile6.nc
# Skipping  land_cubic.00310101-00351231.vegn_temp_max.tile6.nc
# Skipping  land_cubic.00310101-00351231.vegn_temp_min.tile6.nc
# Skipping  land_cubic.00360101-00401231.evap_land.tile1.nc
# Skipping  land_cubic.00360101-00401231.npp.tile1.nc
# Skipping  land_cubic.00360101-00401231.precip.tile1.nc
# Skipping  land_cubic.00360101-00401231.runf_soil.tile1.nc
# Skipping  land_cubic.00360101-00401231.snow_lake.tile1.nc
# Skipping  land_cubic.00360101-00401231.snow_soil.tile1.nc
# Skipping  land_cubic.00360101-00401231.soil_ice.tile1.nc
# Skipping  land_cubic.00360101-00401231.soil_liq.tile1.nc
# Skipping  land_cubic.00360101-00401231.t_ref_max.tile1.nc
# Skipping  land_cubic.00360101-00401231.t_ref_min.tile1.nc
# Skipping  land_cubic.00360101-00401231.vegn_temp_max.tile1.nc
# Skipping  land_cubic.00360101-00401231.vegn_temp_min.tile1.nc
# Skipping  land_cubic.00360101-00401231.evap_land.tile2.nc
# Skipping  land_cubic.00360101-00401231.npp.tile2.nc
# Skipping  land_cubic.00360101-00401231.precip.tile2.nc
# Skipping  land_cubic.00360101-00401231.runf_soil.tile2.nc
# Skipping  land_cubic.00360101-00401231.snow_lake.tile2.nc
# Skipping  land_cubic.00360101-00401231.snow_soil.tile2.nc
# Skipping  land_cubic.00360101-00401231.soil_ice.tile2.nc
# Skipping  land_cubic.00360101-00401231.soil_liq.tile2.nc
# Skipping  land_cubic.00360101-00401231.t_ref_max.tile2.nc
# Skipping  land_cubic.00360101-00401231.t_ref_min.tile2.nc
# Skipping  land_cubic.00360101-00401231.vegn_temp_max.tile2.nc
# Skipping  land_cubic.00360101-00401231.vegn_temp_min.tile2.nc
# Skipping  land_cubic.00360101-00401231.evap_land.tile3.nc
# Skipping  land_cubic.00360101-00401231.npp.tile3.nc
# Skipping  land_cubic.00360101-00401231.precip.tile3.nc
# Skipping  land_cubic.00360101-00401231.runf_soil.tile3.nc
# Skipping  land_cubic.00360101-00401231.snow_lake.tile3.nc
# Skipping  land_cubic.00360101-00401231.snow_soil.tile3.nc
# Skipping  land_cubic.00360101-00401231.soil_ice.tile3.nc
# Skipping  land_cubic.00360101-00401231.soil_liq.tile3.nc
# Skipping  land_cubic.00360101-00401231.t_ref_max.tile3.nc
# Skipping  land_cubic.00360101-00401231.t_ref_min.tile3.nc
# Skipping  land_cubic.00360101-00401231.vegn_temp_max.tile3.nc
# Skipping  land_cubic.00360101-00401231.vegn_temp_min.tile3.nc
# Skipping  land_cubic.00360101-00401231.evap_land.tile4.nc
# Skipping  land_cubic.00360101-00401231.npp.tile4.nc
# Skipping  land_cubic.00360101-00401231.precip.tile4.nc
# Skipping  land_cubic.00360101-00401231.runf_soil.tile4.nc
# Skipping  land_cubic.00360101-00401231.snow_lake.tile4.nc
# Skipping  land_cubic.00360101-00401231.snow_soil.tile4.nc
# Skipping  land_cubic.00360101-00401231.soil_ice.tile4.nc
# Skipping  land_cubic.00360101-00401231.soil_liq.tile4.nc
# Skipping  land_cubic.00360101-00401231.t_ref_max.tile4.nc
# Skipping  land_cubic.00360101-00401231.t_ref_min.tile4.nc
# Skipping  land_cubic.00360101-00401231.vegn_temp_max.tile4.nc
# Skipping  land_cubic.00360101-00401231.vegn_temp_min.tile4.nc
# Skipping  land_cubic.00360101-00401231.evap_land.tile5.nc
# Skipping  land_cubic.00360101-00401231.npp.tile5.nc
# Skipping  land_cubic.00360101-00401231.precip.tile5.nc
# Skipping  land_cubic.00360101-00401231.runf_soil.tile5.nc
# Skipping  land_cubic.00360101-00401231.snow_lake.tile5.nc
# Skipping  land_cubic.00360101-00401231.snow_soil.tile5.nc
# Skipping  land_cubic.00360101-00401231.soil_ice.tile5.nc
# Skipping  land_cubic.00360101-00401231.soil_liq.tile5.nc
# Skipping  land_cubic.00360101-00401231.t_ref_max.tile5.nc
# Skipping  land_cubic.00360101-00401231.t_ref_min.tile5.nc
# Skipping  land_cubic.00360101-00401231.vegn_temp_max.tile5.nc
# Skipping  land_cubic.00360101-00401231.vegn_temp_min.tile5.nc
# Skipping  land_cubic.00360101-00401231.evap_land.tile6.nc
# Skipping  land_cubic.00360101-00401231.npp.tile6.nc
# Skipping  land_cubic.00360101-00401231.precip.tile6.nc
# Skipping  land_cubic.00360101-00401231.runf_soil.tile6.nc
# Skipping  land_cubic.00360101-00401231.snow_lake.tile6.nc
# Skipping  land_cubic.00360101-00401231.snow_soil.tile6.nc
# Skipping  land_cubic.00360101-00401231.soil_ice.tile6.nc
# Skipping  land_cubic.00360101-00401231.soil_liq.tile6.nc
# Skipping  land_cubic.00360101-00401231.t_ref_max.tile6.nc
# Skipping  land_cubic.00360101-00401231.t_ref_min.tile6.nc
# Skipping  land_cubic.00360101-00401231.vegn_temp_max.tile6.nc
# Skipping  land_cubic.00360101-00401231.vegn_temp_min.tile6.nc
# Skipping  land_cubic.00460101-00501231.evap_land.tile1.nc
# Skipping  land_cubic.00460101-00501231.npp.tile1.nc
# Skipping  land_cubic.00460101-00501231.precip.tile1.nc
# Skipping  land_cubic.00460101-00501231.runf_soil.tile1.nc
# Skipping  land_cubic.00460101-00501231.snow_lake.tile1.nc
# Skipping  land_cubic.00460101-00501231.snow_soil.tile1.nc
# Skipping  land_cubic.00460101-00501231.soil_ice.tile1.nc
# Skipping  land_cubic.00460101-00501231.soil_liq.tile1.nc
# Skipping  land_cubic.00460101-00501231.t_ref_max.tile1.nc
# Skipping  land_cubic.00460101-00501231.t_ref_min.tile1.nc
# Skipping  land_cubic.00460101-00501231.vegn_temp_max.tile1.nc
# Skipping  land_cubic.00460101-00501231.vegn_temp_min.tile1.nc
# Skipping  land_cubic.00460101-00501231.evap_land.tile2.nc
# Skipping  land_cubic.00460101-00501231.npp.tile2.nc
# Skipping  land_cubic.00460101-00501231.precip.tile2.nc
# Skipping  land_cubic.00460101-00501231.runf_soil.tile2.nc
# Skipping  land_cubic.00460101-00501231.snow_lake.tile2.nc
# Skipping  land_cubic.00460101-00501231.snow_soil.tile2.nc
# Skipping  land_cubic.00460101-00501231.soil_ice.tile2.nc
# Skipping  land_cubic.00460101-00501231.soil_liq.tile2.nc
# Skipping  land_cubic.00460101-00501231.t_ref_max.tile2.nc
# Skipping  land_cubic.00460101-00501231.t_ref_min.tile2.nc
# Skipping  land_cubic.00460101-00501231.vegn_temp_max.tile2.nc
# Skipping  land_cubic.00460101-00501231.vegn_temp_min.tile2.nc
# Skipping  land_cubic.00460101-00501231.evap_land.tile3.nc
# Skipping  land_cubic.00460101-00501231.npp.tile3.nc
# Skipping  land_cubic.00460101-00501231.precip.tile3.nc
# Skipping  land_cubic.00460101-00501231.runf_soil.tile3.nc
# Skipping  land_cubic.00460101-00501231.snow_lake.tile3.nc
# Skipping  land_cubic.00460101-00501231.snow_soil.tile3.nc
# Skipping  land_cubic.00460101-00501231.soil_ice.tile3.nc
# Skipping  land_cubic.00460101-00501231.soil_liq.tile3.nc
# Skipping  land_cubic.00460101-00501231.t_ref_max.tile3.nc
# Skipping  land_cubic.00460101-00501231.t_ref_min.tile3.nc
# Skipping  land_cubic.00460101-00501231.vegn_temp_max.tile3.nc
# Skipping  land_cubic.00460101-00501231.vegn_temp_min.tile3.nc
# Skipping  land_cubic.00460101-00501231.evap_land.tile4.nc
# Skipping  land_cubic.00460101-00501231.npp.tile4.nc
# Skipping  land_cubic.00460101-00501231.precip.tile4.nc
# Skipping  land_cubic.00460101-00501231.runf_soil.tile4.nc
# Skipping  land_cubic.00460101-00501231.snow_lake.tile4.nc
# Skipping  land_cubic.00460101-00501231.snow_soil.tile4.nc
# Skipping  land_cubic.00460101-00501231.soil_ice.tile4.nc
# Skipping  land_cubic.00460101-00501231.soil_liq.tile4.nc
# Skipping  land_cubic.00460101-00501231.t_ref_max.tile4.nc
# Skipping  land_cubic.00460101-00501231.t_ref_min.tile4.nc
# Skipping  land_cubic.00460101-00501231.vegn_temp_max.tile4.nc
# Skipping  land_cubic.00460101-00501231.vegn_temp_min.tile4.nc
# Skipping  land_cubic.00460101-00501231.evap_land.tile5.nc
# Skipping  land_cubic.00460101-00501231.npp.tile5.nc
# Skipping  land_cubic.00460101-00501231.precip.tile5.nc
# Skipping  land_cubic.00460101-00501231.runf_soil.tile5.nc
# Skipping  land_cubic.00460101-00501231.snow_lake.tile5.nc
# Skipping  land_cubic.00460101-00501231.snow_soil.tile5.nc
# Skipping  land_cubic.00460101-00501231.soil_ice.tile5.nc
# Skipping  land_cubic.00460101-00501231.soil_liq.tile5.nc
# Skipping  land_cubic.00460101-00501231.t_ref_max.tile5.nc
# Skipping  land_cubic.00460101-00501231.t_ref_min.tile5.nc
# Skipping  land_cubic.00460101-00501231.vegn_temp_max.tile5.nc
# Skipping  land_cubic.00460101-00501231.vegn_temp_min.tile5.nc
# Skipping  land_cubic.00460101-00501231.evap_land.tile6.nc
# Skipping  land_cubic.00460101-00501231.npp.tile6.nc
# Skipping  land_cubic.00460101-00501231.precip.tile6.nc
# Skipping  land_cubic.00460101-00501231.runf_soil.tile6.nc
# Skipping  land_cubic.00460101-00501231.snow_lake.tile6.nc
# Skipping  land_cubic.00460101-00501231.snow_soil.tile6.nc
# Skipping  land_cubic.00460101-00501231.soil_ice.tile6.nc
# Skipping  land_cubic.00460101-00501231.soil_liq.tile6.nc
# Skipping  land_cubic.00460101-00501231.t_ref_max.tile6.nc
# Skipping  land_cubic.00460101-00501231.t_ref_min.tile6.nc
# Skipping  land_cubic.00460101-00501231.vegn_temp_max.tile6.nc
# Skipping  land_cubic.00460101-00501231.vegn_temp_min.tile6.nc
# Skipping  land_cubic.00510101-00551231.evap_land.tile1.nc
# Skipping  land_cubic.00510101-00551231.npp.tile1.nc
# Skipping  land_cubic.00510101-00551231.precip.tile1.nc
# Skipping  land_cubic.00510101-00551231.runf_soil.tile1.nc
# Skipping  land_cubic.00510101-00551231.snow_lake.tile1.nc
# Skipping  land_cubic.00510101-00551231.snow_soil.tile1.nc
# Skipping  land_cubic.00510101-00551231.soil_ice.tile1.nc
# Skipping  land_cubic.00510101-00551231.soil_liq.tile1.nc
# Skipping  land_cubic.00510101-00551231.t_ref_max.tile1.nc
# Skipping  land_cubic.00510101-00551231.t_ref_min.tile1.nc
# Skipping  land_cubic.00510101-00551231.vegn_temp_max.tile1.nc
# Skipping  land_cubic.00510101-00551231.vegn_temp_min.tile1.nc
# Skipping  land_cubic.00510101-00551231.evap_land.tile2.nc
# Skipping  land_cubic.00510101-00551231.npp.tile2.nc
# Skipping  land_cubic.00510101-00551231.precip.tile2.nc
# Skipping  land_cubic.00510101-00551231.runf_soil.tile2.nc
# Skipping  land_cubic.00510101-00551231.snow_lake.tile2.nc
# Skipping  land_cubic.00510101-00551231.snow_soil.tile2.nc
# Skipping  land_cubic.00510101-00551231.soil_ice.tile2.nc
# Skipping  land_cubic.00510101-00551231.soil_liq.tile2.nc
# Skipping  land_cubic.00510101-00551231.t_ref_max.tile2.nc
# Skipping  land_cubic.00510101-00551231.t_ref_min.tile2.nc
# Skipping  land_cubic.00510101-00551231.vegn_temp_max.tile2.nc
# Skipping  land_cubic.00510101-00551231.vegn_temp_min.tile2.nc
# Skipping  land_cubic.00510101-00551231.evap_land.tile3.nc
# Skipping  land_cubic.00510101-00551231.npp.tile3.nc
# Skipping  land_cubic.00510101-00551231.precip.tile3.nc
# Skipping  land_cubic.00510101-00551231.runf_soil.tile3.nc
# Skipping  land_cubic.00510101-00551231.snow_lake.tile3.nc
# Skipping  land_cubic.00510101-00551231.snow_soil.tile3.nc
# Skipping  land_cubic.00510101-00551231.soil_ice.tile3.nc
# Skipping  land_cubic.00510101-00551231.soil_liq.tile3.nc
# Skipping  land_cubic.00510101-00551231.t_ref_max.tile3.nc
# Skipping  land_cubic.00510101-00551231.t_ref_min.tile3.nc
# Skipping  land_cubic.00510101-00551231.vegn_temp_max.tile3.nc
# Skipping  land_cubic.00510101-00551231.vegn_temp_min.tile3.nc
# Skipping  land_cubic.00510101-00551231.evap_land.tile4.nc
# Skipping  land_cubic.00510101-00551231.npp.tile4.nc
# Skipping  land_cubic.00510101-00551231.precip.tile4.nc
# Skipping  land_cubic.00510101-00551231.runf_soil.tile4.nc
# Skipping  land_cubic.00510101-00551231.snow_lake.tile4.nc
# Skipping  land_cubic.00510101-00551231.snow_soil.tile4.nc
# Skipping  land_cubic.00510101-00551231.soil_ice.tile4.nc
# Skipping  land_cubic.00510101-00551231.soil_liq.tile4.nc
# Skipping  land_cubic.00510101-00551231.t_ref_max.tile4.nc
# Skipping  land_cubic.00510101-00551231.t_ref_min.tile4.nc
# Skipping  land_cubic.00510101-00551231.vegn_temp_max.tile4.nc
# Skipping  land_cubic.00510101-00551231.vegn_temp_min.tile4.nc
# Skipping  land_cubic.00510101-00551231.evap_land.tile5.nc
# Skipping  land_cubic.00510101-00551231.npp.tile5.nc
# Skipping  land_cubic.00510101-00551231.precip.tile5.nc
# Skipping  land_cubic.00510101-00551231.runf_soil.tile5.nc
# Skipping  land_cubic.00510101-00551231.snow_lake.tile5.nc
# Skipping  land_cubic.00510101-00551231.snow_soil.tile5.nc
# Skipping  land_cubic.00510101-00551231.soil_ice.tile5.nc
# Skipping  land_cubic.00510101-00551231.soil_liq.tile5.nc
# Skipping  land_cubic.00510101-00551231.t_ref_max.tile5.nc
# Skipping  land_cubic.00510101-00551231.t_ref_min.tile5.nc
# Skipping  land_cubic.00510101-00551231.vegn_temp_max.tile5.nc
# Skipping  land_cubic.00510101-00551231.vegn_temp_min.tile5.nc
# Skipping  land_cubic.00510101-00551231.evap_land.tile6.nc
# Skipping  land_cubic.00510101-00551231.npp.tile6.nc
# Skipping  land_cubic.00510101-00551231.precip.tile6.nc
# Skipping  land_cubic.00510101-00551231.runf_soil.tile6.nc
# Skipping  land_cubic.00510101-00551231.snow_lake.tile6.nc
# Skipping  land_cubic.00510101-00551231.snow_soil.tile6.nc
# Skipping  land_cubic.00510101-00551231.soil_ice.tile6.nc
# Skipping  land_cubic.00510101-00551231.soil_liq.tile6.nc
# Skipping  land_cubic.00510101-00551231.t_ref_max.tile6.nc
# Skipping  land_cubic.00510101-00551231.t_ref_min.tile6.nc
# Skipping  land_cubic.00510101-00551231.vegn_temp_max.tile6.nc
# Skipping  land_cubic.00510101-00551231.vegn_temp_min.tile6.nc
# Skipping  land_cubic.00560101-00601231.evap_land.tile1.nc
# Skipping  land_cubic.00560101-00601231.npp.tile1.nc
# Skipping  land_cubic.00560101-00601231.precip.tile1.nc
# Skipping  land_cubic.00560101-00601231.runf_soil.tile1.nc
# Skipping  land_cubic.00560101-00601231.snow_lake.tile1.nc
# Skipping  land_cubic.00560101-00601231.snow_soil.tile1.nc
# Skipping  land_cubic.00560101-00601231.soil_ice.tile1.nc
# Skipping  land_cubic.00560101-00601231.soil_liq.tile1.nc
# Skipping  land_cubic.00560101-00601231.t_ref_max.tile1.nc
# Skipping  land_cubic.00560101-00601231.t_ref_min.tile1.nc
# Skipping  land_cubic.00560101-00601231.vegn_temp_max.tile1.nc
# Skipping  land_cubic.00560101-00601231.vegn_temp_min.tile1.nc
# Skipping  land_cubic.00560101-00601231.evap_land.tile2.nc
# Skipping  land_cubic.00560101-00601231.npp.tile2.nc
# Skipping  land_cubic.00560101-00601231.precip.tile2.nc
# Skipping  land_cubic.00560101-00601231.runf_soil.tile2.nc
# Skipping  land_cubic.00560101-00601231.snow_lake.tile2.nc
# Skipping  land_cubic.00560101-00601231.snow_soil.tile2.nc
# Skipping  land_cubic.00560101-00601231.soil_ice.tile2.nc
# Skipping  land_cubic.00560101-00601231.soil_liq.tile2.nc
# Skipping  land_cubic.00560101-00601231.t_ref_max.tile2.nc
# Skipping  land_cubic.00560101-00601231.t_ref_min.tile2.nc
# Skipping  land_cubic.00560101-00601231.vegn_temp_max.tile2.nc
# Skipping  land_cubic.00560101-00601231.vegn_temp_min.tile2.nc
# Skipping  land_cubic.00560101-00601231.evap_land.tile3.nc
# Skipping  land_cubic.00560101-00601231.npp.tile3.nc
# Skipping  land_cubic.00560101-00601231.precip.tile3.nc
# Skipping  land_cubic.00560101-00601231.runf_soil.tile3.nc
# Skipping  land_cubic.00560101-00601231.snow_lake.tile3.nc
# Skipping  land_cubic.00560101-00601231.snow_soil.tile3.nc
# Skipping  land_cubic.00560101-00601231.soil_ice.tile3.nc
# Skipping  land_cubic.00560101-00601231.soil_liq.tile3.nc
# Skipping  land_cubic.00560101-00601231.t_ref_max.tile3.nc
# Skipping  land_cubic.00560101-00601231.t_ref_min.tile3.nc
# Skipping  land_cubic.00560101-00601231.vegn_temp_max.tile3.nc
# Skipping  land_cubic.00560101-00601231.vegn_temp_min.tile3.nc
# Skipping  land_cubic.00560101-00601231.evap_land.tile4.nc
# Skipping  land_cubic.00560101-00601231.npp.tile4.nc
# Skipping  land_cubic.00560101-00601231.precip.tile4.nc
# Skipping  land_cubic.00560101-00601231.runf_soil.tile4.nc
# Skipping  land_cubic.00560101-00601231.snow_lake.tile4.nc
# Skipping  land_cubic.00560101-00601231.snow_soil.tile4.nc
# Skipping  land_cubic.00560101-00601231.soil_ice.tile4.nc
# Skipping  land_cubic.00560101-00601231.soil_liq.tile4.nc
# Skipping  land_cubic.00560101-00601231.t_ref_max.tile4.nc
# Skipping  land_cubic.00560101-00601231.t_ref_min.tile4.nc
# Skipping  land_cubic.00560101-00601231.vegn_temp_max.tile4.nc
# Skipping  land_cubic.00560101-00601231.vegn_temp_min.tile4.nc
# Skipping  land_cubic.00560101-00601231.evap_land.tile5.nc
# Skipping  land_cubic.00560101-00601231.npp.tile5.nc
# Skipping  land_cubic.00560101-00601231.precip.tile5.nc
# Skipping  land_cubic.00560101-00601231.runf_soil.tile5.nc
# Skipping  land_cubic.00560101-00601231.snow_lake.tile5.nc
# Skipping  land_cubic.00560101-00601231.snow_soil.tile5.nc
# Skipping  land_cubic.00560101-00601231.soil_ice.tile5.nc
# Skipping  land_cubic.00560101-00601231.soil_liq.tile5.nc
# Skipping  land_cubic.00560101-00601231.t_ref_max.tile5.nc
# Skipping  land_cubic.00560101-00601231.t_ref_min.tile5.nc
# Skipping  land_cubic.00560101-00601231.vegn_temp_max.tile5.nc
# Skipping  land_cubic.00560101-00601231.vegn_temp_min.tile5.nc
# Skipping  land_cubic.00560101-00601231.evap_land.tile6.nc
# Skipping  land_cubic.00560101-00601231.npp.tile6.nc
# Skipping  land_cubic.00560101-00601231.precip.tile6.nc
# Skipping  land_cubic.00560101-00601231.runf_soil.tile6.nc
# Skipping  land_cubic.00560101-00601231.snow_lake.tile6.nc
# Skipping  land_cubic.00560101-00601231.snow_soil.tile6.nc
# Skipping  land_cubic.00560101-00601231.soil_ice.tile6.nc
# Skipping  land_cubic.00560101-00601231.soil_liq.tile6.nc
# Skipping  land_cubic.00560101-00601231.t_ref_max.tile6.nc
# Skipping  land_cubic.00560101-00601231.t_ref_min.tile6.nc
# Skipping  land_cubic.00560101-00601231.vegn_temp_max.tile6.nc
# Skipping  land_cubic.00560101-00601231.vegn_temp_min.tile6.nc
# Skipping  land_cubic.000101-000512.glac_T.tile1.nc
# Skipping  land_cubic.000101-000512.albedo_dif.tile1.nc
# Skipping  land_cubic.000101-000512.gpp.tile1.nc
# Skipping  land_cubic.000101-000512.albedo_dir.tile1.nc
# Skipping  land_cubic.000101-000512.lwdn.tile1.nc
# Skipping  land_cubic.000101-000512.an_cl.tile1.nc
# Skipping  land_cubic.000101-000512.LWS.tile1.nc
# Skipping  land_cubic.000101-000512.an_op.tile1.nc
# Skipping  land_cubic.000101-000512.grnd_flux.tile1.nc
# ...
# Skipping  river_cubic.005601-006012.dis_liq.tile3.nc
# Skipping  river_cubic.005601-006012.FWSr.tile3.nc
# Skipping  river_cubic.005601-006012.LWSr.tile3.nc
# Skipping  river_cubic.005601-006012.rv_depth.tile3.nc
# Skipping  river_cubic.005601-006012.rv_d_h2o.tile3.nc
# Skipping  river_cubic.005601-006012.rv_d_hEt.tile3.nc
# Skipping  river_cubic.005601-006012.rv_d_ice.tile3.nc
# Skipping  river_cubic.005601-006012.rv_ice.tile3.nc
# Skipping  river_cubic.005601-006012.rv_i_h2o.tile3.nc
# Skipping  river_cubic.005601-006012.rv_i_het.tile3.nc
# Skipping  river_cubic.005601-006012.rv_i_ice.tile3.nc
# Skipping  river_cubic.005601-006012.rv_o_h2o.tile3.nc
# Skipping  river_cubic.005601-006012.rv_o_het.tile3.nc
# Skipping  river_cubic.005601-006012.rv_o_ice.tile3.nc
# Skipping  river_cubic.005601-006012.rv_Qavg.tile3.nc
# Skipping  river_cubic.005601-006012.rv_T.tile3.nc
# Skipping  river_cubic.005601-006012.rv_veloc.tile3.nc
# Skipping  river_cubic.005601-006012.rv_width.tile3.nc
# Skipping  river_cubic.005601-006012.dis_heat.tile4.nc
# Skipping  river_cubic.005601-006012.dis_ice.tile4.nc
# Skipping  river_cubic.005601-006012.dis_liq.tile4.nc
# Skipping  river_cubic.005601-006012.FWSr.tile4.nc
# Skipping  river_cubic.005601-006012.LWSr.tile4.nc
# Skipping  river_cubic.005601-006012.rv_depth.tile4.nc
# Skipping  river_cubic.005601-006012.rv_d_h2o.tile4.nc
# Skipping  river_cubic.005601-006012.rv_d_hEt.tile4.nc
# Skipping  river_cubic.005601-006012.rv_d_ice.tile4.nc
# Skipping  river_cubic.005601-006012.rv_ice.tile4.nc
# Skipping  river_cubic.005601-006012.rv_i_h2o.tile4.nc
# Skipping  river_cubic.005601-006012.rv_i_het.tile4.nc
# Skipping  river_cubic.005601-006012.rv_i_ice.tile4.nc
# Skipping  river_cubic.005601-006012.rv_o_h2o.tile4.nc
# Skipping  river_cubic.005601-006012.rv_o_het.tile4.nc
# Skipping  river_cubic.005601-006012.rv_o_ice.tile4.nc
# Skipping  river_cubic.005601-006012.rv_Qavg.tile4.nc
# Skipping  river_cubic.005601-006012.rv_T.tile4.nc
# Skipping  river_cubic.005601-006012.rv_veloc.tile4.nc
# Skipping  river_cubic.005601-006012.rv_width.tile4.nc
# Skipping  river_cubic.005601-006012.dis_heat.tile5.nc
# Skipping  river_cubic.005601-006012.dis_ice.tile5.nc
# Skipping  river_cubic.005601-006012.dis_liq.tile5.nc
# Skipping  river_cubic.005601-006012.FWSr.tile5.nc
# Skipping  river_cubic.005601-006012.LWSr.tile5.nc
# Skipping  river_cubic.005601-006012.rv_depth.tile5.nc
# Skipping  river_cubic.005601-006012.rv_d_h2o.tile5.nc
# Skipping  river_cubic.005601-006012.rv_d_hEt.tile5.nc
# Skipping  river_cubic.005601-006012.rv_d_ice.tile5.nc
# Skipping  river_cubic.005601-006012.rv_ice.tile5.nc
# Skipping  river_cubic.005601-006012.rv_i_h2o.tile5.nc
# Skipping  river_cubic.005601-006012.rv_i_het.tile5.nc
# Skipping  river_cubic.005601-006012.rv_i_ice.tile5.nc
# Skipping  river_cubic.005601-006012.rv_o_h2o.tile5.nc
# Skipping  river_cubic.005601-006012.rv_o_het.tile5.nc
# Skipping  river_cubic.005601-006012.rv_o_ice.tile5.nc
# Skipping  river_cubic.005601-006012.rv_Qavg.tile5.nc
# Skipping  river_cubic.005601-006012.rv_T.tile5.nc
# Skipping  river_cubic.005601-006012.rv_veloc.tile5.nc
# Skipping  river_cubic.005601-006012.rv_width.tile5.nc
# Skipping  river_cubic.005601-006012.dis_heat.tile6.nc
# Skipping  river_cubic.005601-006012.dis_ice.tile6.nc
# Skipping  river_cubic.005601-006012.dis_liq.tile6.nc
# Skipping  river_cubic.005601-006012.FWSr.tile6.nc
# Skipping  river_cubic.005601-006012.LWSr.tile6.nc
# Skipping  river_cubic.005601-006012.rv_depth.tile6.nc
# Skipping  river_cubic.005601-006012.rv_d_h2o.tile6.nc
# Skipping  river_cubic.005601-006012.rv_d_hEt.tile6.nc
# Skipping  river_cubic.005601-006012.rv_d_ice.tile6.nc
# Skipping  river_cubic.005601-006012.rv_ice.tile6.nc
# Skipping  river_cubic.005601-006012.rv_i_h2o.tile6.nc
# Skipping  river_cubic.005601-006012.rv_i_het.tile6.nc
# Skipping  river_cubic.005601-006012.rv_i_ice.tile6.nc
# Skipping  river_cubic.005601-006012.rv_o_h2o.tile6.nc
# Skipping  river_cubic.005601-006012.rv_o_het.tile6.nc
# Skipping  river_cubic.005601-006012.rv_o_ice.tile6.nc
# Skipping  river_cubic.005601-006012.rv_Qavg.tile6.nc
# Skipping  river_cubic.005601-006012.rv_T.tile6.nc
# Skipping  river_cubic.005601-006012.rv_veloc.tile6.nc
# Skipping  river_cubic.005601-006012.rv_width.tile6.nc
# Skipping  river_instant_cubic.000601-001012.LWSr.tile4.nc
# Skipping  river_instant_cubic.000101-000512.FWSr.tile1.nc
# Skipping  river_instant_cubic.000601-001012.HSr.tile5.nc
# Skipping  river_instant_cubic.000101-000512.HSr.tile1.nc
# Skipping  river_instant_cubic.000601-001012.FWSr.tile5.nc
# Skipping  river_instant_cubic.000101-000512.LWSr.tile1.nc
# Skipping  river_instant_cubic.000601-001012.LWSr.tile5.nc
# Skipping  river_instant_cubic.000101-000512.FWSr.tile2.nc
# Skipping  river_instant_cubic.000601-001012.FWSr.tile6.nc
# Skipping  river_instant_cubic.000101-000512.HSr.tile2.nc
# Skipping  river_instant_cubic.000601-001012.HSr.tile6.nc
# Skipping  river_instant_cubic.000101-000512.LWSr.tile2.nc
# Skipping  river_instant_cubic.000601-001012.LWSr.tile6.nc
# Skipping  river_instant_cubic.000101-000512.FWSr.tile3.nc
# Skipping  river_instant_cubic.001101-001512.FWSr.tile1.nc
# Skipping  river_instant_cubic.000101-000512.HSr.tile3.nc
# Skipping  river_instant_cubic.001101-001512.HSr.tile1.nc
# Skipping  river_instant_cubic.000101-000512.LWSr.tile3.nc
# Skipping  river_instant_cubic.001101-001512.FWSr.tile3.nc
# Skipping  river_instant_cubic.000101-000512.FWSr.tile4.nc
# Skipping  river_instant_cubic.001101-001512.LWSr.tile2.nc
# Skipping  river_instant_cubic.000101-000512.HSr.tile4.nc
# Skipping  river_instant_cubic.001101-001512.HSr.tile3.nc
# Skipping  river_instant_cubic.000101-000512.LWSr.tile4.nc
# Skipping  river_instant_cubic.001101-001512.LWSr.tile3.nc
# Skipping  river_instant_cubic.000101-000512.FWSr.tile5.nc
# Skipping  river_instant_cubic.001101-001512.FWSr.tile4.nc
# Skipping  river_instant_cubic.000101-000512.HSr.tile5.nc
# Skipping  river_instant_cubic.001101-001512.HSr.tile4.nc
# Skipping  river_instant_cubic.000101-000512.LWSr.tile5.nc
# Skipping  river_instant_cubic.001101-001512.LWSr.tile4.nc
# Skipping  river_instant_cubic.000101-000512.FWSr.tile6.nc
# Skipping  river_instant_cubic.001101-001512.FWSr.tile5.nc
# Skipping  river_instant_cubic.000101-000512.HSr.tile6.nc
# Skipping  river_instant_cubic.001101-001512.HSr.tile5.nc
# Skipping  river_instant_cubic.000101-000512.LWSr.tile6.nc
# Skipping  river_instant_cubic.001101-001512.LWSr.tile5.nc
# Skipping  river_instant_cubic.000601-001012.FWSr.tile1.nc
# Skipping  river_instant_cubic.001101-001512.FWSr.tile6.nc
# Skipping  river_instant_cubic.000601-001012.HSr.tile1.nc
# Skipping  river_instant_cubic.001101-001512.HSr.tile6.nc
# Skipping  river_instant_cubic.000601-001012.LWSr.tile1.nc
# Skipping  river_instant_cubic.001101-001512.LWSr.tile6.nc
# Skipping  river_instant_cubic.000601-001012.FWSr.tile2.nc
# Skipping  river_instant_cubic.001601-002012.FWSr.tile1.nc
# Skipping  river_instant_cubic.000601-001012.HSr.tile2.nc
# Skipping  river_instant_cubic.001601-002012.HSr.tile1.nc
# Skipping  river_instant_cubic.000601-001012.LWSr.tile2.nc
# Skipping  river_instant_cubic.001601-002012.LWSr.tile1.nc
# Skipping  river_instant_cubic.000601-001012.FWSr.tile3.nc
# Skipping  river_instant_cubic.001601-002012.FWSr.tile2.nc
# Skipping  river_instant_cubic.000601-001012.HSr.tile3.nc
# Skipping  river_instant_cubic.001601-002012.HSr.tile2.nc
# Skipping  river_instant_cubic.000601-001012.LWSr.tile3.nc
# Skipping  river_instant_cubic.001601-002012.LWSr.tile2.nc
# Skipping  river_instant_cubic.000601-001012.FWSr.tile4.nc
# Skipping  river_instant_cubic.001601-002012.FWSr.tile3.nc
# Skipping  river_instant_cubic.000601-001012.HSr.tile4.nc
# Skipping  river_instant_cubic.001101-001512.LWSr.tile1.nc
# Skipping  river_instant_cubic.001601-002012.HSr.tile3.nc
# Skipping  river_instant_cubic.001101-001512.FWSr.tile2.nc
# Skipping  river_instant_cubic.001101-001512.HSr.tile2.nc
# Skipping  river_instant_cubic.001601-002012.LWSr.tile3.nc
# Skipping  river_instant_cubic.001601-002012.FWSr.tile4.nc
# Skipping  river_instant_cubic.001601-002012.HSr.tile4.nc
# Skipping  river_instant_cubic.001601-002012.LWSr.tile4.nc
# Skipping  river_instant_cubic.001601-002012.FWSr.tile5.nc
# Skipping  river_instant_cubic.001601-002012.HSr.tile5.nc
# Skipping  river_instant_cubic.001601-002012.LWSr.tile5.nc
# Skipping  river_instant_cubic.001601-002012.FWSr.tile6.nc
# Skipping  river_instant_cubic.001601-002012.HSr.tile6.nc
# Skipping  river_instant_cubic.001601-002012.LWSr.tile6.nc
# Skipping  river_instant_cubic.002101-002512.FWSr.tile1.nc
# Skipping  river_instant_cubic.002101-002512.HSr.tile1.nc
# Skipping  river_instant_cubic.002101-002512.LWSr.tile1.nc
# Skipping  river_instant_cubic.002101-002512.FWSr.tile2.nc
# Skipping  river_instant_cubic.002101-002512.HSr.tile2.nc
# Skipping  river_instant_cubic.002101-002512.LWSr.tile2.nc
# Skipping  river_instant_cubic.002101-002512.FWSr.tile3.nc
# Skipping  river_instant_cubic.002101-002512.HSr.tile3.nc
# Skipping  river_instant_cubic.002101-002512.LWSr.tile3.nc
# Skipping  river_instant_cubic.002101-002512.FWSr.tile4.nc
# Skipping  river_instant_cubic.002101-002512.HSr.tile4.nc
# Skipping  river_instant_cubic.002101-002512.LWSr.tile4.nc
# Skipping  river_instant_cubic.002101-002512.FWSr.tile5.nc
# Skipping  river_instant_cubic.002101-002512.HSr.tile5.nc
# Skipping  river_instant_cubic.002101-002512.LWSr.tile5.nc
# Skipping  river_instant_cubic.002101-002512.FWSr.tile6.nc
# Skipping  river_instant_cubic.002101-002512.HSr.tile6.nc
# Skipping  river_instant_cubic.002101-002512.LWSr.tile6.nc
# Skipping  river_instant_cubic.002601-003012.FWSr.tile1.nc
# Skipping  river_instant_cubic.002601-003012.HSr.tile1.nc
# Skipping  river_instant_cubic.002601-003012.LWSr.tile1.nc
# Skipping  river_instant_cubic.002601-003012.FWSr.tile2.nc
# Skipping  river_instant_cubic.002601-003012.HSr.tile2.nc
# Skipping  river_instant_cubic.002601-003012.LWSr.tile2.nc
# Skipping  river_instant_cubic.002601-003012.FWSr.tile3.nc
# Skipping  river_instant_cubic.002601-003012.HSr.tile3.nc
# Skipping  river_instant_cubic.002601-003012.LWSr.tile3.nc
# Skipping  river_instant_cubic.002601-003012.FWSr.tile4.nc
# Skipping  river_instant_cubic.002601-003012.HSr.tile4.nc
# Skipping  river_instant_cubic.002601-003012.LWSr.tile4.nc
# Skipping  river_instant_cubic.002601-003012.FWSr.tile5.nc
# Skipping  river_instant_cubic.002601-003012.HSr.tile5.nc
# Skipping  river_instant_cubic.002601-003012.LWSr.tile5.nc
# Skipping  river_instant_cubic.002601-003012.FWSr.tile6.nc
# Skipping  river_instant_cubic.002601-003012.HSr.tile6.nc
# Skipping  river_instant_cubic.002601-003012.LWSr.tile6.nc
# Skipping  river_instant_cubic.003101-003512.FWSr.tile1.nc
# Skipping  river_instant_cubic.003101-003512.HSr.tile1.nc
# Skipping  river_instant_cubic.003101-003512.LWSr.tile1.nc
# Skipping  river_instant_cubic.003101-003512.FWSr.tile2.nc
# Skipping  river_instant_cubic.003101-003512.HSr.tile2.nc
# Skipping  river_instant_cubic.003101-003512.LWSr.tile2.nc
# Skipping  river_instant_cubic.003101-003512.FWSr.tile3.nc
# Skipping  river_instant_cubic.003101-003512.HSr.tile3.nc
# Skipping  river_instant_cubic.003101-003512.LWSr.tile3.nc
# Skipping  river_instant_cubic.003101-003512.FWSr.tile4.nc
# Skipping  river_instant_cubic.003101-003512.HSr.tile4.nc
# Skipping  river_instant_cubic.003101-003512.LWSr.tile4.nc
# Skipping  river_instant_cubic.003101-003512.FWSr.tile5.nc
# Skipping  river_instant_cubic.003101-003512.HSr.tile5.nc
# Skipping  river_instant_cubic.003101-003512.LWSr.tile5.nc
# Skipping  river_instant_cubic.003101-003512.FWSr.tile6.nc
# Skipping  river_instant_cubic.003101-003512.HSr.tile6.nc
# Skipping  river_instant_cubic.003101-003512.LWSr.tile6.nc
# Skipping  river_instant_cubic.003601-004012.FWSr.tile1.nc
# Skipping  river_instant_cubic.003601-004012.HSr.tile1.nc
# Skipping  river_instant_cubic.003601-004012.LWSr.tile1.nc
# Skipping  river_instant_cubic.003601-004012.FWSr.tile2.nc
# Skipping  river_instant_cubic.003601-004012.HSr.tile2.nc
# Skipping  river_instant_cubic.003601-004012.LWSr.tile2.nc
# Skipping  river_instant_cubic.003601-004012.FWSr.tile3.nc
# Skipping  river_instant_cubic.003601-004012.HSr.tile3.nc
# Skipping  river_instant_cubic.003601-004012.LWSr.tile3.nc
# Skipping  river_instant_cubic.003601-004012.FWSr.tile4.nc
# Skipping  river_instant_cubic.003601-004012.HSr.tile4.nc
# Skipping  river_instant_cubic.003601-004012.LWSr.tile4.nc
# Skipping  river_instant_cubic.003601-004012.FWSr.tile5.nc
# Skipping  river_instant_cubic.003601-004012.HSr.tile5.nc
# Skipping  river_instant_cubic.003601-004012.LWSr.tile5.nc
# Skipping  river_instant_cubic.003601-004012.FWSr.tile6.nc
# Skipping  river_instant_cubic.003601-004012.HSr.tile6.nc
# Skipping  river_instant_cubic.003601-004012.LWSr.tile6.nc
# Skipping  river_instant_cubic.004601-005012.FWSr.tile1.nc
# Skipping  river_instant_cubic.004601-005012.HSr.tile1.nc
# Skipping  river_instant_cubic.004601-005012.LWSr.tile1.nc
# Skipping  river_instant_cubic.004601-005012.FWSr.tile2.nc
# Skipping  river_instant_cubic.004601-005012.HSr.tile2.nc
# Skipping  river_instant_cubic.004601-005012.LWSr.tile2.nc
# Skipping  river_instant_cubic.004601-005012.FWSr.tile3.nc
# Skipping  river_instant_cubic.004601-005012.HSr.tile3.nc
# Skipping  river_instant_cubic.004601-005012.LWSr.tile3.nc
# Skipping  river_instant_cubic.004601-005012.FWSr.tile4.nc
# Skipping  river_instant_cubic.004601-005012.HSr.tile4.nc
# Skipping  river_instant_cubic.004601-005012.LWSr.tile4.nc
# Skipping  river_instant_cubic.004601-005012.FWSr.tile5.nc
# Skipping  river_instant_cubic.004601-005012.HSr.tile5.nc
# Skipping  river_instant_cubic.004601-005012.LWSr.tile5.nc
# Skipping  river_instant_cubic.004601-005012.FWSr.tile6.nc
# Skipping  river_instant_cubic.004601-005012.HSr.tile6.nc
# Skipping  river_instant_cubic.004601-005012.LWSr.tile6.nc
# Skipping  river_instant_cubic.005101-005512.FWSr.tile1.nc
# Skipping  river_instant_cubic.005101-005512.HSr.tile1.nc
# Skipping  river_instant_cubic.005101-005512.LWSr.tile1.nc
# Skipping  river_instant_cubic.005101-005512.FWSr.tile2.nc
# Skipping  river_instant_cubic.005101-005512.HSr.tile2.nc
# Skipping  river_instant_cubic.005101-005512.LWSr.tile2.nc
# Skipping  river_instant_cubic.005101-005512.FWSr.tile3.nc
# Skipping  river_instant_cubic.005101-005512.HSr.tile3.nc
# Skipping  river_instant_cubic.005101-005512.LWSr.tile3.nc
# Skipping  river_instant_cubic.005101-005512.FWSr.tile4.nc
# Skipping  river_instant_cubic.005101-005512.HSr.tile4.nc
# Skipping  river_instant_cubic.005101-005512.LWSr.tile4.nc
# Skipping  river_instant_cubic.005101-005512.FWSr.tile5.nc
# Skipping  river_instant_cubic.005101-005512.HSr.tile5.nc
# Skipping  river_instant_cubic.005101-005512.LWSr.tile5.nc
# Skipping  river_instant_cubic.005101-005512.FWSr.tile6.nc
# Skipping  river_instant_cubic.005101-005512.HSr.tile6.nc
# Skipping  river_instant_cubic.005101-005512.LWSr.tile6.nc
# Skipping  river_instant_cubic.005601-006012.FWSr.tile1.nc
# Skipping  river_instant_cubic.005601-006012.HSr.tile1.nc
# Skipping  river_instant_cubic.005601-006012.LWSr.tile1.nc
# Skipping  river_instant_cubic.005601-006012.FWSr.tile2.nc
# Skipping  river_instant_cubic.005601-006012.HSr.tile2.nc
# Skipping  river_instant_cubic.005601-006012.LWSr.tile2.nc
# Skipping  river_instant_cubic.005601-006012.FWSr.tile3.nc
# Skipping  river_instant_cubic.005601-006012.HSr.tile3.nc
# Skipping  river_instant_cubic.005601-006012.LWSr.tile3.nc
# Skipping  river_instant_cubic.005601-006012.FWSr.tile4.nc
# Skipping  river_instant_cubic.005601-006012.HSr.tile4.nc
# Skipping  river_instant_cubic.005601-006012.LWSr.tile4.nc
# Skipping  river_instant_cubic.005601-006012.FWSr.tile5.nc
# Skipping  river_instant_cubic.005601-006012.HSr.tile5.nc
# Skipping  river_instant_cubic.005601-006012.LWSr.tile5.nc
# Skipping  river_instant_cubic.005601-006012.FWSr.tile6.nc
# Skipping  river_instant_cubic.005601-006012.HSr.tile6.nc
# Skipping  river_instant_cubic.005601-006012.LWSr.tile6.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Skipping  .fregrid_remap_file_288_by_180.nc
# Found existing file! Overwrite? (y/n) y
# writing..
# JSON generated at: /home/a1r/tests/mycatalog-jpk.json
# CSV generated at: /home/a1r/tests/mycatalog-jpk.csv

# %% [markdown]
# Let's begin our analysis

# %%
import intake, intake_esm
import matplotlib #do a pip install of tools needed in your env or from the notebook
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
import intake, intake_esm

# %%
col_url = "/home/a1r/tests/mycatalog-jpk.json"
col = intake.open_esm_datastore(col_url)

# %% [markdown]
# Explore the catalog

# %%
col.df
# Out:
#       activity_id  institution_id source_id                experiment_id  \
# 0             dev             NaN       fre  CM4.5v01_om5b06_piC_noBLING
# 1             dev             NaN       fre  CM4.5v01_om5b06_piC_noBLING
# 2             dev             NaN       fre  CM4.5v01_om5b06_piC_noBLING
# 3             dev             NaN       fre  CM4.5v01_om5b06_piC_noBLING
# 4             dev             NaN       fre  CM4.5v01_om5b06_piC_noBLING
# ...           ...             ...       ...                          ...
# 10000         dev             NaN       fre  CM4.5v01_om5b06_piC_noBLING
# 10001         dev             NaN       fre  CM4.5v01_om5b06_piC_noBLING
# 10002         dev             NaN       fre  CM4.5v01_om5b06_piC_noBLING
# 10003         dev             NaN       fre  CM4.5v01_om5b06_piC_noBLING
# 10004         dev             NaN       fre  CM4.5v01_om5b06_piC_noBLING
#
#       frequency        realm  table_id  member_id  grid_label variable_id  \
# 0           day  ocean_daily       NaN        NaN         NaN     zos_min
# 1           day  ocean_daily       NaN        NaN         NaN      mlotst
# 2           day  ocean_daily       NaN        NaN         NaN    omldamax
# 3           day  ocean_daily       NaN        NaN         NaN         zos
# 4           day  ocean_daily       NaN        NaN         NaN         sos
# ...         ...          ...       ...        ...         ...         ...
# 10000       mon        river       NaN        NaN         NaN    rv_o_ice
# 10001       mon        river       NaN        NaN         NaN     rv_Qavg
# 10002       mon        river       NaN        NaN         NaN        rv_T
# 10003       mon        river       NaN        NaN         NaN    rv_veloc
# 10004       mon        river       NaN        NaN         NaN    rv_width
#
#               time_range chunk_freq                        platform  \
# 0      00110101-00151231        5yr  gfdl.ncrc5-intel23-prod-openmp
# 1      00010101-00051231        5yr  gfdl.ncrc5-intel23-prod-openmp
# 2      00010101-00051231        5yr  gfdl.ncrc5-intel23-prod-openmp
# 3      00110101-00151231        5yr  gfdl.ncrc5-intel23-prod-openmp
# 4      00010101-00051231        5yr  gfdl.ncrc5-intel23-prod-openmp
# ...                  ...        ...                             ...
# 10000      005601-006012        5yr  gfdl.ncrc5-intel23-prod-openmp
# 10001      005601-006012        5yr  gfdl.ncrc5-intel23-prod-openmp
# 10002      005601-006012        5yr  gfdl.ncrc5-intel23-prod-openmp
# 10003      005601-006012        5yr  gfdl.ncrc5-intel23-prod-openmp
# 10004      005601-006012        5yr  gfdl.ncrc5-intel23-prod-openmp
#
#        dimensions cell_methods  \
# 0             NaN           ts
# 1             NaN           ts
# 2             NaN           ts
# 3             NaN           ts
# 4             NaN           ts
# ...           ...          ...
# 10000         NaN           ts
# 10001         NaN           ts
# 10002         NaN           ts
# 10003         NaN           ts
# 10004         NaN           ts
#
#                                            standard_name  \
# 0                                                    NaN
# 1         ocean_mixed_layer_thickness_defined_by_sigma_t
# 2      ocean_mixed_layer_thickness_defined_by_mixing_...
# 3                         sea_surface_height_above_geoid
# 4                                   sea_surface_salinity
# ...                                                  ...
# 10000                                                NaN
# 10001                                                NaN
# 10002                                                NaN
# 10003                                                NaN
# 10004                                                NaN
#
#                                                     path
# 0      /archive/John.Krasting/fre/FMS2024.02_OM5_2024...
# 1      /archive/John.Krasting/fre/FMS2024.02_OM5_2024...
# 2      /archive/John.Krasting/fre/FMS2024.02_OM5_2024...
# 3      /archive/John.Krasting/fre/FMS2024.02_OM5_2024...
# 4      /archive/John.Krasting/fre/FMS2024.02_OM5_2024...
# ...                                                  ...
# 10000  /archive/John.Krasting/fre/FMS2024.02_OM5_2024...
# 10001  /archive/John.Krasting/fre/FMS2024.02_OM5_2024...
# 10002  /archive/John.Krasting/fre/FMS2024.02_OM5_2024...
# 10003  /archive/John.Krasting/fre/FMS2024.02_OM5_2024...
# 10004  /archive/John.Krasting/fre/FMS2024.02_OM5_2024...
#
# [10005 rows x 17 columns]

# %% [markdown]
# Let's narrow down the search

# %%
expname_filter = ['CM4.5v01_om5b06_piC_noBLING']
modeling_realm = "ocean_monthly"
frequency = "mon"

# %%
cat = col.search(experiment_id=expname_filter,frequency=frequency,realm=modeling_realm)

# %%
set(cat.df["variable_id"])
# Out:
# {'Heat_PmE',
#  'LwLatSens',
#  'MLD_003',
#  'MLD_003_max',
#  'MLD_003_min',
#  'MLD_EN1',
#  'MLD_EN1_max',
#  'MLD_EN1_min',
#  'MLD_EN2',
#  'MLD_EN3',
#  'SSH',
#  'S_adx_2d',
#  'S_ady_2d',
#  'T_adx_2d',
#  'T_ady_2d',
#  'col_height',
#  'col_mass',
#  'ePBL_h_ML',
#  'evs',
#  'ficeberg',
#  'friver',
#  'fsitherm',
#  'heat_content_cond',
#  'heat_content_fprec',
#  'heat_content_massin',
#  'heat_content_massout',
#  'heat_content_surfwater',
#  'heat_content_vprec',
#  'hf_CAu_2d',
#  'hf_CAv_2d',
#  'hf_PFu_2d',
#  'hf_PFv_2d',
#  'hf_diffu_2d',
#  'hf_diffv_2d',
#  'hf_du_dt_visc_2d',
#  'hf_dudt_2d',
#  'hf_dv_dt_visc_2d',
#  'hf_dvdt_2d',
#  'hf_gKEu_2d',
#  'hf_gKEv_2d',
#  'hf_rvxu_2d',
#  'hf_rvxv_2d',
#  'hf_u_BT_accel_2d',
#  'hf_v_BT_accel_2d',
#  'hfds',
#  'hfevapds',
#  'hfibthermds',
#  'hflso',
#  'hfrainds',
#  'hfrunoffds',
#  'hfsifrazil',
#  'hfsnthermds',
#  'hfsso',
#  'intz_CAu_2d',
#  'intz_CAv_2d',
#  'intz_PFu_2d',
#  'intz_PFv_2d',
#  'intz_diffu_2d',
#  'intz_diffv_2d',
#  'intz_gKEu_2d',
#  'intz_gKEv_2d',
#  'intz_rvxu_2d',
#  'intz_rvxv_2d',
#  'intz_u_BT_accel_2d',
#  'intz_v_BT_accel_2d',
#  'mass_wt',
#  'net_heat_coupler',
#  'net_massin',
#  'net_massout',
#  'nonpenSW',
#  'opottempmint',
#  'pbo',
#  'prlq',
#  'prsn',
#  'rlntds',
#  'rsdo',
#  'rsntds',
#  'salt_flux_added',
#  'sfdsi',
#  'sob',
#  'somint',
#  'sos',
#  'ssh_ga',
#  'tauuo',
#  'tauvo',
#  'taux',
#  'taux_bot',
#  'tauy',
#  'tauy_bot',
#  'tob',
#  'tos',
#  'ubt_dt',
#  'umo_2d',
#  'ustar',
#  'vbt_dt',
#  'vmo_2d',
#  'volcello',
#  'vprec',
#  'wfo',
#  'zos',
#  'zossq'}

# %%
cat = cat.search(variable_id="sos") #Total Soil Moisture Content

# %% [markdown]
# dmget the files

# %%
cat
# Out:
# <p><strong>esm_catalog_ESM4 catalog with 11 dataset(s) from 11 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>time_range</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>chunk_freq</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>platform</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>dimensions</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>cell_methods</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>standard_name</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#for simple dmget usage, just use this !dmget {file}
#use following to wrap the dmget call for each path in the catalog
def dmgetmagic(x):
    cmd = 'dmget %s'% str(x) 
    return os.system(cmd)

#OR refer to importing dmget ,  https://github.com/aradhakrishnanGFDL/canopy-cats/tree/main/notebooks/dmget.py

# %%
dmstatus = cat.df["path"].apply(dmgetmagic)

# %%
dset_dict = cat.to_dataset_dict(cdf_kwargs={'chunks': {'time':5}, 'decode_times': True})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'source_id.experiment_id.frequency.realm.chunk_freq.time_range'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='11' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [11/11 00:00&lt;00:00]
#     </div>

# %%
for k in dset_dict.keys(): 
    print(k)
# Out:
# fre.CM4.5v01_om5b06_piC_noBLING.mon.ocean_monthly.5yr.000601-001012
# fre.CM4.5v01_om5b06_piC_noBLING.mon.ocean_monthly.5yr.000101-000512
# fre.CM4.5v01_om5b06_piC_noBLING.mon.ocean_monthly.5yr.004601-005012
# fre.CM4.5v01_om5b06_piC_noBLING.mon.ocean_monthly.5yr.002601-003012
# fre.CM4.5v01_om5b06_piC_noBLING.mon.ocean_monthly.5yr.002101-002512
# fre.CM4.5v01_om5b06_piC_noBLING.mon.ocean_monthly.5yr.001601-002012
# fre.CM4.5v01_om5b06_piC_noBLING.mon.ocean_monthly.5yr.003101-003512
# fre.CM4.5v01_om5b06_piC_noBLING.mon.ocean_monthly.5yr.003601-004012
# fre.CM4.5v01_om5b06_piC_noBLING.mon.ocean_monthly.5yr.005101-005512
# fre.CM4.5v01_om5b06_piC_noBLING.mon.ocean_monthly.5yr.005601-006012
# fre.CM4.5v01_om5b06_piC_noBLING.mon.ocean_monthly.5yr.001101-001512

# %%
ds = dset_dict[k]

# %%
ds
# Out:
# <xarray.Dataset> Size: 401MB
# Dimensions:     (time: 60, nv: 2, yh: 1161, xh: 1440)
# Coordinates:
#   * nv          (nv) float64 16B 1.0 2.0
#   * time        (time) object 480B 0011-01-16 12:00:00 ... 0015-12-16 12:00:00
#   * xh          (xh) float64 12kB -299.9 -299.6 -299.4 ... 59.38 59.62 59.88
#   * yh          (yh) float64 9kB -88.52 -88.42 -88.32 ... 89.73 89.84 89.95
# Data variables:
#     average_DT  (time) timedelta64[ns] 480B dask.array<chunksize=(5,), meta=np.ndarray>
#     average_T1  (time) object 480B dask.array<chunksize=(5,), meta=np.ndarray>
#     average_T2  (time) object 480B dask.array<chunksize=(5,), meta=np.ndarray>
#     sos         (time, yh, xh) float32 401MB dask.array<chunksize=(5, 1161, 1440), meta=np.ndarray>
#     time_bnds   (time, nv) object 960B dask.array<chunksize=(5, 2), meta=np.ndarray>
# Attributes: (12/20)
#     title:                           CM4.5v01_om5b06_piC_noBLING
#     associated_files:                areacello: 00110101.ocean_static.nc
#     grid_type:                       regular
#     grid_tile:                       N/A
#     external_variables:              areacello
#     intake_esm_vars:                 ['sos']
#     ...                              ...
#     intake_esm_attrs:platform:       gfdl.ncrc5-intel23-prod-openmp
#     intake_esm_attrs:cell_methods:   ts
#     intake_esm_attrs:standard_name:  sea_surface_salinity
#     intake_esm_attrs:path:           /archive/John.Krasting/fre/FMS2024.02_OM...
#     intake_esm_attrs:_data_format_:  netcdf
#     intake_esm_dataset_key:          fre.CM4.5v01_om5b06_piC_noBLING.mon.ocea...

# %%
ds["sos"]
# Out:
# <xarray.DataArray 'sos' (time: 60, yh: 1161, xh: 1440)> Size: 401MB
# dask.array<open_dataset-sos, shape=(60, 1161, 1440), dtype=float32, chunksize=(5, 1161, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 480B 0011-01-16 12:00:00 ... 0015-12-16 12:00:00
#   * xh       (xh) float64 12kB -299.9 -299.6 -299.4 -299.1 ... 59.38 59.62 59.88
#   * yh       (yh) float64 9kB -88.52 -88.42 -88.32 -88.23 ... 89.73 89.84 89.95
# Attributes:
#     units:          psu
#     long_name:      Sea Surface Salinity
#     cell_methods:   area:mean yh:mean xh:mean time: mean
#     cell_measures:  area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  sea_surface_salinity

# %%
sos = ds.sos.isel(time=1).plot()

# %%
ds.sos.mean(dim='time').plot()
